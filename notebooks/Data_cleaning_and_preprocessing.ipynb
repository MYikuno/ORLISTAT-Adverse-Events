# %%
##import libraries
import pandas as pd
import numpy as np
import os
import glob
from functools import reduce
import missingno as msno
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
import ast
import plotly.express as px

# %%
##read data
ten_yrs_data = pd.read_csv("/content/drive/MyDrive/Ten_years_data.csv", dtype = str)

# %%
##display data
ten_yrs_data.head()
# Out:
#     primaryid    caseid caseversion i_f_code  event_dt    mfr_dt init_fda_dt  \
# 0   120963692  12096369           2        F      2007  20200326    20160220
# 1  1314962521  13149625          21        F      2017  20200218    20170125
# 2  1352573513  13525735          13        F  20170417  20191223    20170509
# 3   147306292  14730629           2        F  20180226  20200227    20180406
# 4   148324085  14832408           5        F  20080514  20200114    20180501
#
#      fda_dt rept_cod              auth_num  ... dose_unit  \
# 0  20200331      EXP                   NaN  ...       NaN
# 1  20200302      EXP                   NaN  ...       NaN
# 2  20200106      EXP                   NaN  ...       NaN
# 3  20200309      EXP  GB-MHRA-ADR 24296496  ...       NaN
# 4  20200122      EXP                   NaN  ...       NaN
#
#                 dose_form dose_freq indi_drug_seq  \
# 0                     NaN       NaN           NaN
# 1                     NaN       NaN           NaN
# 2                     NaN       NaN            21
# 3  SOLUTION FOR INJECTION       NaN             1
# 4                     NaN       NaN            41
#
#                                indi_pt dsg_drug_seq start_dt    end_dt  dur  \
# 0                                  NaN          NaN      NaN       NaN  NaN
# 1                                  NaN           17     2006       NaN  NaN
# 2  Product used for unknown indication          NaN      NaN       NaN  NaN
# 3                    Diabetes mellitus            1      NaN  20180226  NaN
# 4                     Weight decreased           41     2007       NaN  NaN
#
#   dur_cod
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#
# [5 rows x 52 columns]

# %% [markdown]
# **Data Cleaning**

# %%
## data information
ten_yrs_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19324 entries, 0 to 19323
# Data columns (total 52 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   primaryid         19324 non-null  object
#  1   caseid            19324 non-null  object
#  2   caseversion       19324 non-null  object
#  3   i_f_code          19324 non-null  object
#  4   event_dt          8400 non-null   object
#  5   mfr_dt            18935 non-null  object
#  6   init_fda_dt       19324 non-null  object
#  7   fda_dt            19324 non-null  object
#  8   rept_cod          19324 non-null  object
#  9   auth_num          1370 non-null   object
#  10  mfr_num           18890 non-null  object
#  11  mfr_sndr          19262 non-null  object
#  12  lit_ref           579 non-null    object
#  13  age               10826 non-null  object
#  14  age_cod           10827 non-null  object
#  15  age_grp           4044 non-null   object
#  16  sex               16515 non-null  object
#  17  e_sub             19324 non-null  object
#  18  wt                3807 non-null   object
#  19  wt_cod            3807 non-null   object
#  20  rept_dt           19319 non-null  object
#  21  to_mfr            2280 non-null   object
#  22  occp_cod          19174 non-null  object
#  23  reporter_country  19324 non-null  object
#  24  occr_country      18984 non-null  object
#  25  outc_cod          8641 non-null   object
#  26  pt                19324 non-null  object
#  27  drug_seq          19324 non-null  object
#  28  role_cod          19324 non-null  object
#  29  drugname          19324 non-null  object
#  30  prod_ai           19321 non-null  object
#  31  val_vbm           19324 non-null  object
#  32  route             11352 non-null  object
#  33  dose_vbm          15292 non-null  object
#  34  cum_dose_chr      393 non-null    object
#  35  cum_dose_unit     393 non-null    object
#  36  dechal            10956 non-null  object
#  37  rechal            5924 non-null   object
#  38  lot_num           10737 non-null  object
#  39  exp_dt            80 non-null     object
#  40  nda_num           14618 non-null  object
#  41  dose_amt          5688 non-null   object
#  42  dose_unit         5688 non-null   object
#  43  dose_form         12516 non-null  object
#  44  dose_freq         4730 non-null   object
#  45  indi_drug_seq     15256 non-null  object
#  46  indi_pt           15256 non-null  object
#  47  dsg_drug_seq      7743 non-null   object
#  48  start_dt          7145 non-null   object
#  49  end_dt            3874 non-null   object
#  50  dur               567 non-null    object
#  51  dur_cod           567 non-null    object
# dtypes: object(52)
# memory usage: 7.7+ MB

# %%
##convert data types

##conver the ff cols into numeric
cols_to_convert = ['primaryid', 'caseid', 'caseversion', 'age', 'wt', 'drug_seq', 'val_vbm',
                  'indi_drug_seq', 'dsg_drug_seq', 'nda_num', 'dose_amt', 'dur']

ten_yrs_data[cols_to_convert] = ten_yrs_data[cols_to_convert].apply(lambda col: pd.to_numeric(col, errors="coerce"))

##convert the ff cols into date
cols_to_date = ['event_dt', 'mfr_dt', 'init_fda_dt','fda_dt', 'rept_dt',
                'exp_dt', 'start_dt', 'end_dt']

ten_yrs_data[cols_to_date] = ten_yrs_data[cols_to_date].apply(lambda col: pd.to_datetime(col, errors = 'coerce'))

##display info
ten_yrs_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19324 entries, 0 to 19323
# Data columns (total 52 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   primaryid         19324 non-null  int64
#  1   caseid            19324 non-null  int64
#  2   caseversion       19324 non-null  int64
#  3   i_f_code          19324 non-null  object
#  4   event_dt          991 non-null    datetime64[ns]
#  5   mfr_dt            18935 non-null  datetime64[ns]
#  6   init_fda_dt       19324 non-null  datetime64[ns]
#  7   fda_dt            19324 non-null  datetime64[ns]
#  8   rept_cod          19324 non-null  object
#  9   auth_num          1370 non-null   object
#  10  mfr_num           18890 non-null  object
#  11  mfr_sndr          19262 non-null  object
#  12  lit_ref           579 non-null    object
#  13  age               10826 non-null  float64
#  14  age_cod           10827 non-null  object
#  15  age_grp           4044 non-null   object
#  16  sex               16515 non-null  object
#  17  e_sub             19324 non-null  object
#  18  wt                3807 non-null   float64
#  19  wt_cod            3807 non-null   object
#  20  rept_dt           19319 non-null  datetime64[ns]
#  21  to_mfr            2280 non-null   object
#  22  occp_cod          19174 non-null  object
#  23  reporter_country  19324 non-null  object
#  24  occr_country      18984 non-null  object
#  25  outc_cod          8641 non-null   object
#  26  pt                19324 non-null  object
#  27  drug_seq          19324 non-null  int64
#  28  role_cod          19324 non-null  object
#  29  drugname          19324 non-null  object
#  30  prod_ai           19321 non-null  object
#  31  val_vbm           19324 non-null  int64
#  32  route             11352 non-null  object
#  33  dose_vbm          15292 non-null  object
#  34  cum_dose_chr      393 non-null    object
#  35  cum_dose_unit     393 non-null    object
#  36  dechal            10956 non-null  object
#  37  rechal            5924 non-null   object
#  38  lot_num           10737 non-null  object
#  39  exp_dt            80 non-null     datetime64[ns]
#  40  nda_num           14618 non-null  float64
#  41  dose_amt          5688 non-null   float64
#  42  dose_unit         5688 non-null   object
#  43  dose_form         12516 non-null  object
#  44  dose_freq         4730 non-null   object
#  45  indi_drug_seq     15256 non-null  float64
#  46  indi_pt           15256 non-null  object
#  47  dsg_drug_seq      7743 non-null   float64
#  48  start_dt          1042 non-null   datetime64[ns]
#  49  end_dt            2609 non-null   datetime64[ns]
#  50  dur               567 non-null    float64
#  51  dur_cod           567 non-null    object
# dtypes: datetime64[ns](8), float64(7), int64(5), object(32)
# memory usage: 7.7+ MB

# %%
##data set summary
ten_yrs_data.describe()
# Out:
#           primaryid        caseid   caseversion  \
# count  1.932400e+04  1.932400e+04  19324.000000
# mean   1.813224e+08  1.660592e+07      1.516922
# min    6.964033e+07  6.964033e+06      1.000000
# 25%    1.293475e+08  1.290103e+07      1.000000
# 50%    1.601319e+08  1.601312e+07      1.000000
# 75%    2.050214e+08  2.031193e+07      1.000000
# max    2.373172e+09  2.479141e+07     95.000000
# std    1.619005e+08  4.200208e+06      2.201272
#
#                             event_dt                         mfr_dt  \
# count                            991                          18935
# mean   2016-06-20 00:39:13.985872896  2019-04-20 13:41:24.731977984
# min              1991-01-01 00:00:00            1999-02-24 00:00:00
# 25%              2016-01-01 00:00:00            2016-09-30 00:00:00
# 50%              2017-01-01 00:00:00            2019-01-02 00:00:00
# 75%              2018-01-01 00:00:00            2021-12-17 00:00:00
# max              2021-01-01 00:00:00            2024-12-26 00:00:00
# std                              NaN                            NaN
#
#                          init_fda_dt                      fda_dt  \
# count                          19324                       19324
# mean   2019-06-02 08:27:41.767749888  2019-07-22 18:01:11.537984
# min              2009-04-08 00:00:00         2014-07-01 00:00:00
# 25%              2016-11-01 00:00:00         2016-12-23 00:00:00
# 50%              2019-02-27 00:00:00         2019-02-27 00:00:00
# 75%              2022-01-08 00:00:00         2022-02-22 00:00:00
# max              2024-12-31 00:00:00         2024-12-31 00:00:00
# std                              NaN                         NaN
#
#                 age           wt                        rept_dt      drug_seq  \
# count  10826.000000  3807.000000                          19319  19324.000000
# mean     153.052004    99.402734  2019-07-20 01:07:45.303587328      5.020544
# min        0.000000     2.900000            2007-01-17 00:00:00      1.000000
# 25%       42.000000    81.000000            2016-12-23 00:00:00      1.000000
# 50%       52.000000    95.000000            2019-02-27 00:00:00      1.000000
# 75%       62.000000   112.335000            2022-02-22 00:00:00      2.000000
# max    27989.000000   446.000000            2024-12-31 00:00:00    558.000000
# std     1430.519084    29.729863                            NaN     20.851839
#
#        val_vbm               exp_dt       nda_num     dose_amt  indi_drug_seq  \
# count  19324.0                   80  1.461800e+04  5688.000000   15256.000000
# mean       1.0  2020-10-27 17:42:00  1.531051e+05    10.756593       4.401219
# min        1.0  2010-07-13 00:00:00  9.900000e+01     0.060000       1.000000
# 25%        1.0  2018-03-23 12:00:00  2.188700e+04     1.000000       1.000000
# 50%        1.0  2020-06-30 00:00:00  2.063210e+05     1.800000       1.000000
# 75%        1.0  2023-09-30 00:00:00  2.063210e+05     3.000000       1.000000
# max        1.0  2026-07-31 00:00:00  1.980710e+08  1800.000000     541.000000
# std        0.0                  NaN  2.317210e+06    51.072810      20.299455
#
#        dsg_drug_seq                       start_dt  \
# count   7743.000000                           1042
# mean       2.543717  2015-10-26 19:04:15.662188032
# min        1.000000            1976-01-01 00:00:00
# 25%        1.000000            2015-01-01 00:00:00
# 50%        1.000000            2017-01-01 00:00:00
# 75%        2.000000            2019-01-01 00:00:00
# max      183.000000            2024-01-01 00:00:00
# std        6.351161                            NaN
#
#                               end_dt          dur
# count                           2609   567.000000
# mean   2019-04-08 08:53:10.187811328    67.315697
# min              1998-10-14 00:00:00     1.000000
# 25%              2016-11-01 00:00:00     4.500000
# 50%              2019-01-17 00:00:00    14.000000
# 75%              2022-01-02 00:00:00    60.500000
# max              2024-12-19 00:00:00  2920.000000
# std                              NaN   190.731734

# %%
##Missing values

##null counts
print(ten_yrs_data.isnull().sum())
# Out:
# primaryid               0
# caseid                  0
# caseversion             0
# i_f_code                0
# event_dt            18333
# mfr_dt                389
# init_fda_dt             0
# fda_dt                  0
# rept_cod                0
# auth_num            17954
# mfr_num               434
# mfr_sndr               62
# lit_ref             18745
# age                  8498
# age_cod              8497
# age_grp             15280
# sex                  2809
# e_sub                   0
# wt                  15517
# wt_cod              15517
# rept_dt                 5
# to_mfr              17044
# occp_cod              150
# reporter_country        0
# occr_country          340
# outc_cod            10683
# pt                      0
# drug_seq                0
# role_cod                0
# drugname                0
# prod_ai                 3
# val_vbm                 0
# route                7972
# dose_vbm             4032
# cum_dose_chr        18931
# cum_dose_unit       18931
# dechal               8368
# rechal              13400
# lot_num              8587
# exp_dt              19244
# nda_num              4706
# dose_amt            13636
# dose_unit           13636
# dose_form            6808
# dose_freq           14594
# indi_drug_seq        4068
# indi_pt              4068
# dsg_drug_seq        11581
# start_dt            18282
# end_dt              16715
# dur                 18757
# dur_cod             18757
# dtype: int64

# %%
##null values percentage
print((ten_yrs_data.isnull().sum()/len(ten_yrs_data))*100)
# Out:
# primaryid            0.000000
# caseid               0.000000
# caseversion          0.000000
# i_f_code             0.000000
# event_dt            94.871662
# mfr_dt               2.013041
# init_fda_dt          0.000000
# fda_dt               0.000000
# rept_cod             0.000000
# auth_num            92.910371
# mfr_num              2.245912
# mfr_sndr             0.320845
# lit_ref             97.003726
# age                 43.976402
# age_cod             43.971227
# age_grp             79.072656
# sex                 14.536328
# e_sub                0.000000
# wt                  80.299110
# wt_cod              80.299110
# rept_dt              0.025875
# to_mfr              88.201201
# occp_cod             0.776237
# reporter_country     0.000000
# occr_country         1.759470
# outc_cod            55.283585
# pt                   0.000000
# drug_seq             0.000000
# role_cod             0.000000
# drugname             0.000000
# prod_ai              0.015525
# val_vbm              0.000000
# route               41.254399
# dose_vbm            20.865245
# cum_dose_chr        97.966260
# cum_dose_unit       97.966260
# dechal              43.303664
# rechal              69.343821
# lot_num             44.436970
# exp_dt              99.586007
# nda_num             24.353136
# dose_amt            70.565100
# dose_unit           70.565100
# dose_form           35.230801
# dose_freq           75.522666
# indi_drug_seq       21.051542
# indi_pt             21.051542
# dsg_drug_seq        59.930656
# start_dt            94.607742
# end_dt              86.498655
# dur                 97.065825
# dur_cod             97.065825
# dtype: float64

# %%
##visualisation of missing values
##plot
msno.matrix(ten_yrs_data)
plt.show()

# %%
## remove columns with >60% missing values
## remove cols - evt_dt, cum_dose_chr, cum_dose_unit, rechal, exp_dt,
## dose_amt, dose_unit, dose_freq, auth_num, lit_ref, age_grp, to_mfr,
## wt, wt_cod, start_dt, end_dt, dur, dur_cod

##drop cols with more than 60% missing values
ten_yrs_data = ten_yrs_data.dropna(axis=1, thresh=len(ten_yrs_data)*0.4)

##display data
ten_yrs_data
# Out:
#         primaryid    caseid  caseversion i_f_code     mfr_dt init_fda_dt  \
# 0       120963692  12096369            2        F 2020-03-26  2016-02-20
# 1      1314962521  13149625           21        F 2020-02-18  2017-01-25
# 2      1352573513  13525735           13        F 2019-12-23  2017-05-09
# 3       147306292  14730629            2        F 2020-02-27  2018-04-06
# 4       148324085  14832408            5        F 2020-01-14  2018-05-01
# ...           ...       ...          ...      ...        ...         ...
# 19319   172138441  17213844            1        I 2019-12-16  2019-12-30
# 19320   172138441  17213844            1        I 2019-12-16  2019-12-30
# 19321   172138441  17213844            1        I 2019-12-16  2019-12-30
# 19322   172138441  17213844            1        I 2019-12-16  2019-12-30
# 19323   172138441  17213844            1        I 2019-12-16  2019-12-30
#
#           fda_dt rept_cod                         mfr_num      mfr_sndr  ...  \
# 0     2020-03-31      EXP      US-ASTRAZENECA-2008BM06688   ASTRAZENECA  ...
# 1     2020-03-02      EXP  CA-CELLTRION INC.-2017CA000780     CELLTRION  ...
# 2     2020-01-06      EXP                CA-ROCHE-1931885         ROCHE  ...
# 3     2020-03-09      EXP              GB-NOVOPROD-593576  NOVO NORDISK  ...
# 4     2020-01-22      EXP      US-ASTRAZENECA-2018SE50167   ASTRAZENECA  ...
# ...          ...      ...                             ...           ...  ...
# 19319 2019-12-30      EXP       CA-MYLANLABS-2019M1126884         MYLAN  ...
# 19320 2019-12-30      EXP       CA-MYLANLABS-2019M1126884         MYLAN  ...
# 19321 2019-12-30      EXP       CA-MYLANLABS-2019M1126884         MYLAN  ...
# 19322 2019-12-30      EXP       CA-MYLANLABS-2019M1126884         MYLAN  ...
# 19323 2019-12-30      EXP       CA-MYLANLABS-2019M1126884         MYLAN  ...
#
#        val_vbm         route           dose_vbm dechal lot_num  nda_num  \
# 0            1           NaN                NaN    NaN     NaN      NaN
# 1            1       Unknown        UNK, 1X/DAY    NaN     NaN      NaN
# 2            1       Unknown                NaN      U     NaN      NaN
# 3            1  Subcutaneous             1.8 MG    NaN     NaN  22341.0
# 4            1           NaN                NaN    NaN     NaN      NaN
# ...        ...           ...                ...    ...     ...      ...
# 19319        1  Subcutaneous  0.6 MILLIGRAM, QD      D     NaN      NaN
# 19320        1  Subcutaneous  1.8 MILLIGRAM, QD      D     NaN      NaN
# 19321        1  Subcutaneous            UNK UNK      D     NaN      NaN
# 19322        1  Subcutaneous  1.8 MILLIGRAM, QD      D     NaN      NaN
# 19323        1  Subcutaneous            UNK UNK      D     NaN      NaN
#
#                     dose_form indi_drug_seq  \
# 0                         NaN           NaN
# 1                         NaN           NaN
# 2                         NaN          21.0
# 3      SOLUTION FOR INJECTION           1.0
# 4                         NaN          41.0
# ...                       ...           ...
# 19319               INJECTION           NaN
# 19320               INJECTION           NaN
# 19321               INJECTION           NaN
# 19322               INJECTION           NaN
# 19323               INJECTION           NaN
#
#                                    indi_pt dsg_drug_seq
# 0                                      NaN          NaN
# 1                                      NaN         17.0
# 2      Product used for unknown indication          NaN
# 3                        Diabetes mellitus          1.0
# 4                         Weight decreased         41.0
# ...                                    ...          ...
# 19319                                  NaN          NaN
# 19320                                  NaN          NaN
# 19321                                  NaN          NaN
# 19322                                  NaN          NaN
# 19323                                  NaN          NaN
#
# [19324 rows x 34 columns]

# %%
##null values percentage
print((ten_yrs_data.isnull().sum()/len(ten_yrs_data)*100))
# Out:
# primaryid            0.000000
# caseid               0.000000
# caseversion          0.000000
# i_f_code             0.000000
# mfr_dt               2.013041
# init_fda_dt          0.000000
# fda_dt               0.000000
# rept_cod             0.000000
# mfr_num              2.245912
# mfr_sndr             0.320845
# age                 43.976402
# age_cod             43.971227
# sex                 14.536328
# e_sub                0.000000
# rept_dt              0.025875
# occp_cod             0.776237
# reporter_country     0.000000
# occr_country         1.759470
# outc_cod            55.283585
# pt                   0.000000
# drug_seq             0.000000
# role_cod             0.000000
# drugname             0.000000
# prod_ai              0.015525
# val_vbm              0.000000
# route               41.254399
# dose_vbm            20.865245
# dechal              43.303664
# lot_num             44.436970
# nda_num             24.353136
# dose_form           35.230801
# indi_drug_seq       21.051542
# indi_pt             21.051542
# dsg_drug_seq        59.930656
# dtype: float64

# %%
##visualise missing values
msno.matrix(ten_yrs_data)
plt.show()

# %%
##remove rows with less than 10% missing values

# Identify columns with less than 10% missing values
cols_below_10pct_missing = ten_yrs_data.columns[(ten_yrs_data.isnull().mean() > 0) & (ten_yrs_data.isnull().mean() <= 0.1)]

print(cols_below_10pct_missing)
# Out:
# Index(['mfr_dt', 'mfr_num', 'mfr_sndr', 'rept_dt', 'occp_cod', 'occr_country',
#        'prod_ai'],
#       dtype='object')

# %%
# Drop rows where these columns have missing values
ten_yrs_data = ten_yrs_data[~ten_yrs_data[cols_below_10pct_missing].isnull().any(axis=1)]

##display data
ten_yrs_data
# Out:
#         primaryid    caseid  caseversion i_f_code     mfr_dt init_fda_dt  \
# 1      1314962521  13149625           21        F 2020-02-18  2017-01-25
# 2      1352573513  13525735           13        F 2019-12-23  2017-05-09
# 3       147306292  14730629            2        F 2020-02-27  2018-04-06
# 5       151265324  15126532            4        F 2020-01-02  2018-07-10
# 6       152211425  15221142            5        F 2020-01-22  2018-07-31
# ...           ...       ...          ...      ...        ...         ...
# 19319   172138441  17213844            1        I 2019-12-16  2019-12-30
# 19320   172138441  17213844            1        I 2019-12-16  2019-12-30
# 19321   172138441  17213844            1        I 2019-12-16  2019-12-30
# 19322   172138441  17213844            1        I 2019-12-16  2019-12-30
# 19323   172138441  17213844            1        I 2019-12-16  2019-12-30
#
#           fda_dt rept_cod                           mfr_num  \
# 1     2020-03-02      EXP    CA-CELLTRION INC.-2017CA000780
# 2     2020-01-06      EXP                  CA-ROCHE-1931885
# 3     2020-03-09      EXP                GB-NOVOPROD-593576
# 5     2020-01-07      EXP             US-JNJFOC-20180709795
# 6     2020-01-30      EXP  PT-AUROBINDO-AUR-APL-2018-038679
# ...          ...      ...                               ...
# 19319 2019-12-30      EXP         CA-MYLANLABS-2019M1126884
# 19320 2019-12-30      EXP         CA-MYLANLABS-2019M1126884
# 19321 2019-12-30      EXP         CA-MYLANLABS-2019M1126884
# 19322 2019-12-30      EXP         CA-MYLANLABS-2019M1126884
# 19323 2019-12-30      EXP         CA-MYLANLABS-2019M1126884
#
#                   mfr_sndr  ...  val_vbm         route  \
# 1                CELLTRION  ...        1       Unknown
# 2                    ROCHE  ...        1       Unknown
# 3             NOVO NORDISK  ...        1  Subcutaneous
# 5      JOHNSON AND JOHNSON  ...        1       Unknown
# 6                AUROBINDO  ...        1          Oral
# ...                    ...  ...      ...           ...
# 19319                MYLAN  ...        1  Subcutaneous
# 19320                MYLAN  ...        1  Subcutaneous
# 19321                MYLAN  ...        1  Subcutaneous
# 19322                MYLAN  ...        1  Subcutaneous
# 19323                MYLAN  ...        1  Subcutaneous
#
#                         dose_vbm dechal lot_num  nda_num  \
# 1                    UNK, 1X/DAY    NaN     NaN      NaN
# 2                            NaN      U     NaN      NaN
# 3                         1.8 MG    NaN     NaN  22341.0
# 5                            NaN      D     NaN      NaN
# 6      100 MILLIGRAM, ONCE A DAY      Y     NaN      NaN
# ...                          ...    ...     ...      ...
# 19319          0.6 MILLIGRAM, QD      D     NaN      NaN
# 19320          1.8 MILLIGRAM, QD      D     NaN      NaN
# 19321                    UNK UNK      D     NaN      NaN
# 19322          1.8 MILLIGRAM, QD      D     NaN      NaN
# 19323                    UNK UNK      D     NaN      NaN
#
#                     dose_form indi_drug_seq  \
# 1                         NaN           NaN
# 2                         NaN          21.0
# 3      SOLUTION FOR INJECTION           1.0
# 5                         NaN           4.0
# 6                     CAPSULE          17.0
# ...                       ...           ...
# 19319               INJECTION           NaN
# 19320               INJECTION           NaN
# 19321               INJECTION           NaN
# 19322               INJECTION           NaN
# 19323               INJECTION           NaN
#
#                                    indi_pt dsg_drug_seq
# 1                                      NaN         17.0
# 2      Product used for unknown indication          NaN
# 3                        Diabetes mellitus          1.0
# 5      Product used for unknown indication          NaN
# 6                         Weight decreased          NaN
# ...                                    ...          ...
# 19319                                  NaN          NaN
# 19320                                  NaN          NaN
# 19321                                  NaN          NaN
# 19322                                  NaN          NaN
# 19323                                  NaN          NaN
#
# [18661 rows x 34 columns]

# %%
##null values percentage
print((ten_yrs_data.isnull().sum()/len(ten_yrs_data)*100))
# Out:
# primaryid            0.000000
# caseid               0.000000
# caseversion          0.000000
# i_f_code             0.000000
# mfr_dt               0.000000
# init_fda_dt          0.000000
# fda_dt               0.000000
# rept_cod             0.000000
# mfr_num              0.000000
# mfr_sndr             0.000000
# age                 45.142275
# age_cod             45.136917
# sex                 14.934891
# e_sub                0.000000
# rept_dt              0.000000
# occp_cod             0.000000
# reporter_country     0.000000
# occr_country         0.000000
# outc_cod            56.406409
# pt                   0.000000
# drug_seq             0.000000
# role_cod             0.000000
# drugname             0.000000
# prod_ai              0.000000
# val_vbm              0.000000
# route               40.828466
# dose_vbm            19.002197
# dechal              43.030920
# lot_num             42.977332
# nda_num             21.917368
# dose_form           33.481593
# indi_drug_seq       20.288302
# indi_pt             20.288302
# dsg_drug_seq        60.425486
# dtype: float64

# %%
##unique values for age_cod
ten_yrs_data['age_cod'].unique()
# Out:
# array([nan, 'YR', 'MON', 'DY', 'DEC', 'WK'], dtype=object)

# %%
##unique values at sex col
ten_yrs_data['sex'].unique()
# Out:
# array([nan, 'M', 'F'], dtype=object)

# %%
##value counts
ten_yrs_data['sex'].value_counts()
# Out:
# sex
# F    12470
# M     3404
# Name: count, dtype: int64

# %%
##unique values for outc_cod
arr = np.array(ten_yrs_data['outc_cod'])

# Step 1: Flatten and parse the string lists
unique_items = set()
for item in arr:
    if isinstance(item, str):
        try:
            parsed = ast.literal_eval(item)
            unique_items.update(parsed)
        except Exception as e:
            print(f"Error parsing item: {item} | {e}")

# Step 2: Print sorted list of unique values
print(sorted(unique_items))
# Out:
# ['CA', 'DE', 'DS', 'HO', 'LT', 'OT']

# %%
##unique values for route col
ten_yrs_data['route'].unique()
# Out:
# array(['Unknown', 'Subcutaneous', 'Oral', nan, 'Parenteral', 'Other',
#        'Transplacental', 'Intramuscular', 'Rectal', 'Cutaneous',
#        'Endocervical', 'Topical', 'Intravenous (not otherwise specified)',
#        'ORAL', 'UNKNOWN', 'SUBCUTANEOUS', 'TRANSPLACENTAL', 'Intradermal',
#        'Sublingual'], dtype=object)

# %%
##unique values for dose_vbm
ten_yrs_data['dose_vbm'].unique()
# Out:
# array(['UNK, 1X/DAY', nan, '1.8 MG', ..., '0.6 MG, QD(IN MORNING)',
#        '6 MG/DAY, 0-0-1-0', '2.4 MILLIGRAM, QD'], dtype=object)

# %%
##unique values for dechal col
ten_yrs_data['dechal'].unique()
# Out:
# array([nan, 'U', 'D', 'Y', 'N'], dtype=object)

# %%
##value counts for dechal col
ten_yrs_data['dechal'].value_counts()
# Out:
# dechal
# U    6092
# Y    3218
# N     693
# D     628
# Name: count, dtype: int64

# %%
##unique values for lot_num
ten_yrs_data['lot_num'].unique()
# Out:
# array([nan, ' HZF8853', ' HZF9167', ' HZF9734', ' HP53325', ' JZFD436',
#        ' HZF7574', ' JP51557', ' 9812', ' 15234', ' JP51913', ' JP50601',
#        ' UNKNOWN', ' 104571XC', ' UNK', ' JP52967', ' 12356', ' 11495',
#        ' 15994', ' 12355', ' 18200', ' 15233', ' 5790', ' 15615',
#        ' JP51371', ' 8814', ' JP52255', ' JZFG794', ' JZFB266',
#        ' 61906XB', ' HZF7917', ' HZF8459', ' HZF9443', ' HZFA728',
#        ' HZFA073', ' HP53176', ' HZF6071', ' HZFA877', ' HZF7572',
#        ' HZF5680', ' HZFA228', ' HZF7456', ' JZFD205', ' JP50740',
#        ' JZFC391', ' GZF4087', ' HZF7049', ' JZF7572', ' JP51543',
#        ' JZFB691', ' JZFF698', ' JZFF289', ' JZFE564', ' FZF0134',
#        ' HP51867', ' HP50909', ' JZFD433', ' HZF7916', ' JZFB512',
#        ' 9813', ' U NK', ' 11613', ' 104573XC', ' 5511', ' 18593',
#        ' 10947', ' 5276', ' JP53459', ' JZFB511', ' JP53782', ' 18594',
#        ' 5275', ' 5405', ' 18626', ' JP52643', ' 105463XB', ' 20184',
#        ' KS6AK14', ' KZFJ179', ' JZFG972', ' HP52672', ' 15995',
#        ' JP54360', ' JP54127', ' 18595', ' 6353', ' KZFK974', ' JZFG217',
#        ' 20920', ' KP50866', ' KVGY661-1', ' 27611', ' JP53219', ' 20185',
#        ' JP52709', ' KP51448', ' KP50955', ' 98130421', ' KZFM952',
#        ' HP53660', ' 27721', ' 22014', ' 2185', ' KZFH784', ' HP53035',
#        ' UNKNOWN,UNKNOWN,UNKNOWN', ' 6352', ' 27211', ' 6021', ' 22017',
#        ' 27209', ' KZFH742', ' JP53320', ' KZFJ880', ' KZFJ599',
#        ' KZFK654', ' JZFF482', ' KZFN525', ' KZFK972', ' KZFL979',
#        ' KP53101', ' KZFH714', ' 25068', ' KZFP641', ' FP52152',
#        ' KP51097', ' 22015', ' KP52385', ' KP53169', ' KZSP641',
#        ' KP53062', ' JP54048', ' KP54829?1', ' 27212', ' KZFP107',
#        ' KP53227', ' KZFP624', ' KP52001', ' KP55295', ' 31246',
#        ' KP54948', ' 30708', ' LZFR670', ' KP54182', ' 22017E', ' 30709',
#        ' KP54988', ' LZFR616', ' KZFP014', ' 34608', ' 35148', ' LP55582',
#        ' 21N2512866', ' 34288', ' LP55913', 'UNKNOWN', 'Unknown',
#        'HP52822', 'KP52385', '30708', '22015', 'KP53461', 'LP55913',
#        'LP56468', 'LP56216', '104571XC', 'PL 20416/0270', 'P2005101',
#        '35148', 'LZFV032', '30709', 'UNK', '35998', '11495', '27211',
#        'ASKU,ASKU', '38523', '18594', 'LP56167', '34608', '2001471',
#        '105463XB', 'LP55471', 'LP57071', 'JP52991', 'JP51914', 'KP54815',
#        '37236', '35999', '272211', 'JZFB512', 'KZFJ179', 'KZFM952',
#        'KZFL979', 'KZFN525', 'KP53101', 'JZFF698', 'KZSP641', '18626',
#        'LP57105', 'LZFX538', '34288', 'LZF0F81', '27209', '42288',
#        '37237', 'LZFV815', '39261', 'LP58401', 'LP57004', 'KZFP014',
#        'KZFH714', 'KP52210', 'KZFP641', 'KZFPQ14', 'JZF8691', 'JZFG972',
#        'KZFK654', 'KZFP107', 'KZFK974', 'LZFR616', 'LZFR670', 'JZFB511',
#        'kzfr099', 'KZFK126', 'LZFT520', 'JZFG794', 'LZFT537', 'LZFT821',
#        'LZFV816', 'Kzfk654', 'LZFX370', 'LZFX304', 'LZFZ032', 'LZFY190',
#        '43023', '10947', 'LP57040', 'unknown', 'MZF0S63', 'LZF0K63',
#        'LP57907', '22014', 'LZFX926', 'LZFW142', 'LP56107', '39272',
#        '43015', 'LXG0036', 'KP52539', 'MZF1B30', '40645', 'LZFY660',
#        '105463', 'LZF0840', 'LP59623', '41163', 'LZFX706',
#        'UNKNOWN,UNKNOWN,UNKNOWN,UNKNOWN', 'unk', 'HOPE61150', '41164',
#        '40648', '105436XB', 'LP58611', '44099', 'MZF1N94', 'LZFY613',
#        'MP5B231', 'MP5A133', '39523', 'LP57712', 'LZFW928', '46401',
#        'LP59000', 'UNKNOWN,Unknown', 'MZF2S40', 'MP5C224', 'LP59255',
#        'MP5B092', 'MZF1C43', 'MZF1N60', '44102', 'LZF0H19', 'ASKU',
#        'LP57961', 'LP59205', 'B078ZMSLSX', '45401', 'MP5B835', 'LP56380',
#        '39524', 'MP5A921', 'm2431m1', 'Unk', '44101', 'MP5B678',
#        'MZF2E53', 'MZF1H16', 'MZF2W29', 'NEM ISMERT', '40545', 'MZF2M47',
#        'MZF3M95', '44100', 'MZF1A12', 'MP5D463', '45539', 'MZF3P76',
#        'LP56362', 'MZF1B20', '105463xb', '38272', 'MP5B141', 'MZF3K45',
#        'HZFA073', 'KZFR142', 'MZF1B16', 'LZFY612', 'LZFY956', 'MP5A345',
#        'LZFB816', 'LZF0k63', 'MZF1816', 'LZFY554', 'LZF0J91', 'MZF2W41',
#        'LP58257', 'MZF1M53', 'lzfy190', 'Mzf3f62', 'MZF2W43', 'MZF2C80',
#        'MZF2N66', 'MZF2W40', 'MZF3G92', 'mzf1m53', 'mzf2n66', 'F2722A1',
#        'MZF2S43', 'MZF2W30', 'MZF1R96', 'MZF1N53', 'MPFA345', 'lzfy9226',
#        'MZF3V28', '05711249108878', '105463XB/44100', 'MZF4D49',
#        'MZF3L04', 'MZF2544', 'MZF1V54', 'MP5D557', '5279410', '5279407',
#        'MZF1R16', '5346731', 'MP5D606', '346731', '104471xc', 'A3818AA',
#        'MFG3421', '105463xB', 'MZF1T49', 'NZF4N71', 'NP5E909', '15994',
#        'KP51403', 'MZF1B28', '5279409', 'MP5E410', 'NZF4N39', 'NZF5H09',
#        '5346735', 'NZF5B22', 'MP5E428', 'NT69B48', '40622', '5346736',
#        '106468X8', 'NZF4H65', '10756XB', '5421100', 'M2F2W28', 'NP5F049',
#        'MZF2G82', 'NZF5D22', 'NP5F221', '5346737', 'NZF4W91', 'LZFW549',
#        '49219', 'A10BJ02', '5371118', '5346738', '5371123', 'NZF5B74',
#        'NP5E938', 'MP5C880', 'NP56587', 'nzf4r66', 'MZS1520', 'NZF5S85',
#        'MZF 1S20', 'LP57681', 'MZF1B27', '44010', 'MZF2W83', 'NZF6S13',
#        'O5712249105983', '60523', 'NP5F056', '21222', '5647367',
#        '5421103', '5449439', 'NP5H290', 'LZFT174', 'NP5G625', 'MP5C409',
#        'NZF6E14', 'NFG3577', '5601182', 'NP5F273', 'NZF5R66', 'NZF7G65',
#        '5748978', '5371124', 'MZF3F62', 'MZF4816', 'MZF3P04', 'MZF4B16',
#        'mzf4b16', 'NZF4S32', 'MZF4D61', 'NZF5D23', 'NZF5W31', 'nzf5d23',
#        'NZF6M08', 'NZF6e14', 'NP5F682', 'NP5H302', 'nzf6y74', 'nzf4m19',
#        'NT6BN54', '5728770', '5428719', '54494439', '05712249103637',
#        '5403991', 'LZFOA80', '89566', '5449442', 'NP5J567', 'NZF8J12',
#        'NP5H445', 'NP5H186', '5728771', 'NZF7S37', 'mx2313', 'MP5A804',
#        '5728769', '406410624', 'JZFG217', '5748984', '8-9556-97-201-2',
#        'mzf2c80', 'NT69P52', 'MZF2N63', '5748972', '5745972', 'NZF6P34',
#        '5765799', 'TEVA Ltd', 'MP5J397', 'NZF8D71', 'PZF9A63', 'NP5J397',
#        'NZF8E65', '5881223', 'M2468M1', 'NFG3632', '5745970', 'pzf9g71',
#        '60124', '5728772', 'NZF7K96', 'NFG3720', '5886686', 'NZF8E66',
#        'NZF5L77', 'PZF8K87', 'NZF7A37', 'NZF5L76', 'PS6LAK03', '5954620',
#        'NZF7Y86', 'NZF5R48', 'PZF8W07', 'PZF9S04', 'PS6LK12', '5981936',
#        'PZF8W06', '(01) 07798058931768', 'TZF9A63', 'MZF3P07', 'MZF3P0',
#        'PZF9P70', 'PP5L315', 'LP59140', '2405366', '2305456A', 'NP5K079',
#        'PZF9S03', 'PZFAJ87', 'PFG3810', '5967682', 'NI', '5996957',
#        '6043872', 'PP5L387', 'nov 2023', 'MS6HC12', '5967685', 'NZF5R54',
#        'PZF8M99', 'PP5M004', '5822927', 'PP5L523', '1529408105547',
#        ' 13752', ' 14319', ' 13058', ' 14395', ' 13824', ' 14245',
#        ' 13425', ' 13903', ' 14409', ' 14394', ' 14442', ' 14177',
#        ' 5310046925', ' 13562', ' 14706', ' 14287', ' 14028', ' 14470',
#        ' 14246', ' 14372', ' 14283', ' 14535', ' 13595', ' 14124',
#        ' 13834', ' 14422', ' 14075', ' 13852', ' 13901', ' 14077',
#        ' 13324', ' 14200', ' 13835', ' 7F26', ' 13448', ' 14042',
#        ' 13376', ' 13411', ' 7117', ' 14267', ' 13721', ' 14095', ' 8I02',
#        ' 12051', ' 13788', ' 12056', ' 13765', ' 13720', ' 13707',
#        ' 13624', ' 8A16', ' 12169', ' 11496', ' 13596', ' 11820', ' 8J13',
#        ' 14365', ' 13358', ' 12182', ' 13809', ' 13483', ' 13545',
#        ' 12744', ' NOT REPORTED', ' M2142M2', ' 14617', ' 14010',
#        ' 14621', ' 14623', ' 14618', ' 14786', ' 14619', ' 14620',
#        ' 14784', ' 14785', ' 14622', ' 104619', ' 14869', ' 13730',
#        ' 61906XD', ' UKN', ' ORAL', ' 14870', ' 14873', ' 14872',
#        ' 148700', ' 14916', ' 14890', ' EZF0080', ' C2015A', ' EZF0087',
#        ' EZF0199', ' C1715A', ' 14917', ' 14918', ' 14889', ' 4870',
#        ' 14920', ' 11660', ' 14927', ' 14919', ' EZF0066', ' C1415A',
#        ' 14827', ' 14958', ' 14957', ' 14926', ' 14009', ' 14977',
#        ' 14978', ' EZF0362', ' EZF0202', ' EZF0491', ' 14992', ' 46222',
#        ' 14993', ' 14979', ' 14994', ' 15050', ' 14935', ' 61906XD13752',
#        ' 14897', ' 632193', ' 668283', ' 14980', ' FP50335', ' 104571XA',
#        ' EZF0510', ' D0215A', ' EZF0582', ' ES06V443', ' EZF0597',
#        ' EZF0528', ' EZF0679', ' 150A5', ' 4785', ' 15089', ' NOT KNOWN',
#        ' 15085', ' 15084', ' 571XA', ' FZF0030', ' 13810', ' 15086',
#        ' UNSURE', ' 1S084', ' 15087', ' 15088', ' DS6L813', ' FZF0091',
#        ' K1315A', ' FP50135', ' K1915A', ' FP50162', ' 15102', ' 15147',
#        ' FZF0130', ' 15103', ' EP52424', ' 15104', ' D0915A', ' FZF0132',
#        ' FZF0155', ' FZF0335', ' FZF0204', ' EZF0699', ' 149771',
#        ' 15107', ' 15231', ' 15262', ' 20116', ' M2239M2', ' 50216',
#        ' M2215M1', ' FP51814', ' F2316A', ' L0215A', ' FZF0437',
#        ' FZF0336', ' FZF0432', ' 15154', ' FP50921', ' 11D07W', ' 15153',
#        ' FP51476', ' FP52143', ' 15244', ' 15272', ' FP51294', ' 15280',
#        ' 15152', ' 15270', ' 489613', ' M20873M3', ' M2076M4', ' 11758',
#        ' FP51282', ' FP50859', ' 15281', ' 104571XB', ' FZF0507',
#        ' FZF0045', ' FZF0613', ' B2110', ' M1716B01', ' U3003',
#        ' U3006, U3007', ' U3105', ' U3015', ' U3014', ' NOT SPECIFIED',
#        ' 884078', ' 923639,M1003', ' 872084', ' U3004', ' 0166',
#        ' U300050', ' X66333', ' U3006', ' 972121', ' 00858921',
#        ' M1941M1', ' 15308', ' FZF0092', ' 15283', ' 15306', ' GP51716',
#        ' FZF0601', ' GZF0037', ' 104571EA', ' 15347', ' GZF0075',
#        ' 15400', ' 15723', ' H1616A', ' FP53233', ' GZF2423', ' GZF2422',
#        ' GZF2654', ' GP52517', ' 15401', ' 61905XB', ' 15478', ' 15530',
#        ' GP52354', ' H1116B', ' FZF00045', ' 15480', ' 15477', ' 15476',
#        ' GZF3141', ' GZF3227', ' 105463XA', ' GE53273', ' 15463XB',
#        ' 15481', ' 1580', ' 15527', ' 15503', ' GP53506', ' 15500',
#        ' 1547', ' GZF4490', ' 15601', ' GP52922', ' GP53471', ' GP53725',
#        ' 08470007106630', ' HZF5919', ' 18B09N', ' GP54343',
#        ' M2246M4P03', ' M2279M1', ' M2201M3', ' M2218M1', ' M2250M1P23',
#        ' M2227M1-6891', ' M2264MB', ' M2200M1', ' M2238M9', ' M2247M4',
#        ' M2185M1P04', ' M2261M9', ' M2248M9', ' M2196M4U1', ' M2241M3',
#        ' M2185M1PO4,M2138M3P20', ' M2258M2', ' M2266M1', ' M2212M2',
#        ' M2247MC', ' M22474MC', ' 2267M1', ' M2168M1',
#        ' M2233M1, M2191M1, M2253M1', ' NOT PROVIDED', ' M2195M5',
#        ' M2284M4', ' M2236M4', ' M2253M3U1, M2247M1U1', ' M2184M4P47',
#        ' 15602', ' 15616', ' GP53974', ' UNCONFIRMED', ' GZF5231',
#        ' HP50455', ' 4518', ' 12297', ' UKNOWN', ' HP50641', ' HZF6713',
#        ' 5805', ' 5789', ' HZF6410', ' HP51391', ' 5510', ' 5513',
#        ' 104571', ' 551', ' HP50914', ' B6020', ' 6020', ' 6022',
#        ' GP52217', ' HP51353', ' HP50976', ' HP52879', ' M2276M1P61',
#        ' UNKONWN', ' HP51388', ' 8887', ' 6023', ' 7760', ' 9811',
#        ' 8813', ' GP51553', ' HP53127', ' HP52409', ' GP54180',
#        ' GZF5036', ' FZF0156', ' GZF5341', ' GZF0036', ' HP50825',
#        ' UNKOWN', ' 8812', ' 8811', ' 9452', ' GP51032', ' G3118A',
#        ' HP53523', ' 8911', ' HP35888', ' A887', ' 5404', ' 10948',
#        ' 9451', ' JP50732', ' 19047', ' 0041084764805', ' FP52899',
#        ' JP51201', ' JP50963', ' JP52832', ' JP50992'], dtype=object)

# %%
##value counts for nda_num
ten_yrs_data['nda_num'].value_counts()
# Out:
# nda_num
# 206321.0       8190
# 21887.0        5897
# 20766.0         256
# 22341.0         224
# 198071001.0       2
# 75765.0           1
# 7157.0            1
# Name: count, dtype: int64

# %%
##unique values for dose_form
ten_yrs_data['dose_form'].unique()
# Out:
# array([nan, 'SOLUTION FOR INJECTION', 'CAPSULE', 'INJECTION', 'UNK',
#        'UNKNOWN', 'FORMULATION UNKNOWN',
#        'SOLUTION FOR INJECTION/INFUSION', 'TABLETS',
#        'SOLN FOR INJECT IN PRE-FILLED SYRINGE',
#        'SOLUTION FOR INJECTION IN PRE-FILLED PEN', 'UNSPECIFIED',
#        'TABLET', 'CHEWABLE/DISPERSIBLE TABLET', 'CHEWABLE TABLET',
#        'LIQUID', 'Solution for injection', 'Capsule', 'Injection',
#        'Unknown', 'Solution for injection/infusion',
#        'Solution for injection in pre-filled pen', 'Capsules', 'Solution',
#        'Tablet', '5', 'Solution for injection in pre-filled syringe',
#        'prefilled syringes', 'Infusion', 'Formulation unknown',
#        'Chewable/dispersible tablet', 'Oromucosal suspension',
#        'INJECTION, SOLUTION', 'PRE-FILLED SYRINGE', 'Capsule, hard',
#        'CAPSULE, HARD', 'SOLUTION', 'GRANULES'], dtype=object)

# %%
#unique values for indi_drug_seq col
ten_yrs_data['indi_drug_seq'].unique()
# Out:
# array([ nan,  21.,   1.,   4.,  17.,  35.,   5.,   6.,   7.,  14.,  15.,
#         33.,  10.,   3.,   2.,   8.,  12.,   9.,  13.,  16.,  11.,  19.,
#         50.,  18.,  52.,  20.,  43.,  22.,  84.,  26.,  39.,  29.,  31.,
#         27.,  28.,  45.,  36.,  40., 122.,  49.,  55.,  80.,  25., 188.,
#         34.,  24.,  37.,  76.,  57.,  23., 147.,  42., 140., 259., 136.,
#        127., 151., 229.,  60.,  61.,  58., 142., 302., 129., 159.,  54.,
#        189., 130.,  51.,  95., 153., 113., 178., 295., 141., 173.,  94.,
#        116.,  30., 155., 194., 249., 503.,  32., 149., 201., 202., 154.,
#        150., 262., 199., 177., 220., 320., 205.,  85., 218.,  53., 119.,
#        111., 180., 175., 219., 261., 315.,  44.,  62., 216.,  87.,  64.,
#         79., 107., 168., 169.,  47., 133., 512., 152., 183.,  65.,  66.,
#        171., 209., 233., 234., 235., 118., 117.,  91.,  90., 309., 102.,
#         71., 101.,  99., 135., 232., 182., 157., 372., 184., 214., 469.,
#        210., 313., 167., 128.,  38.,  48.,  72.,  69.,  63., 316., 270.,
#        257., 422., 223.,  46., 541.,  67., 265., 472., 121., 279.,  98.,
#         89., 126., 125., 158.,  41., 166.])

# %%
#unique values for indi_pt col
ten_yrs_data['indi_pt'].unique()
# Out:
# array([nan, 'Product used for unknown indication', 'Diabetes mellitus',
#        'Weight decreased', 'Weight control', 'Obesity',
#        'Type 2 diabetes mellitus', 'Hyperglycaemia', 'Weight loss diet',
#        'Anxiety', 'Insulin resistance', 'Glucose tolerance impaired',
#        'Overweight', 'Hypertension', 'Type 1 diabetes mellitus',
#        'Glycosylated haemoglobin abnormal', 'Suicide attempt',
#        'Blood glucose', 'Hyperlipidaemia', 'Abnormal weight gain',
#        'Weight increased', 'Food craving', 'Polycystic ovaries',
#        'Gastrooesophageal reflux disease', 'Body mass index increased',
#        'Premenstrual syndrome', 'Constipation', 'Fat tissue decreased',
#        'Pre-existing disease', 'Dyspepsia',
#        'Insulin-requiring type 2 diabetes mellitus', 'Oedema',
#        'Blood insulin abnormal', 'Diabetic neuropathy',
#        'Blood glucose increased', 'Diabetes mellitus management',
#        'Gastrointestinal disorder', 'Weight', 'Increased appetite',
#        'Medical diet', 'Prophylaxis', 'Blood glucose fluctuation',
#        'Diabetes mellitus inadequate control', 'Metabolic syndrome',
#        'Glycosylated haemoglobin increased', 'Appetite disorder',
#        'Thyroid hormones increased', 'Ill-defined disorder',
#        'Blood glucose abnormal', 'Supplementation therapy', 'Diarrhoea',
#        'Blood glucose decreased', 'Chronic obstructive pulmonary disease',
#        'Depression', 'Blood pressure abnormal', 'Bile acid malabsorption',
#        'Decreased appetite', 'Irritable bowel syndrome',
#        'Hepatic steatosis', 'Maternal exposure during pregnancy',
#        'Prader-Willi syndrome', 'Non-alcoholic steatohepatitis',
#        'Adverse drug reaction', 'Weight loss poor', 'Suspected suicide',
#        'Hormone level abnormal', 'Sleep apnoea syndrome',
#        'Blood cholesterol increased', 'Dyschezia', 'Prostate cancer',
#        'Plasma cell myeloma', 'Illness', 'Nausea', 'Hypoglycaemia',
#        'HIV infection', 'Sensory loss', 'Ascites', 'Dyslipidaemia',
#        'Sleep-related eating disorder', 'Weight abnormal',
#        'Short-bowel syndrome', 'Cardiac disorder',
#        'Polycystic ovarian syndrome', 'Secondary hypertension',
#        'Bipolar disorder', 'Bowel movement irregularity',
#        'Abnormal loss of weight', 'Impaired fasting glucose',
#        'Hypopituitarism', 'Body fat disorder', 'Metabolic disorder',
#        'Hypercholesterolaemia', 'Blood cholesterol',
#        'Symptomatic treatment', 'Frequent bowel movements',
#        'Idiopathic intracranial hypertension', 'Change of bowel habit',
#        'Routine health maintenance', 'Off label use',
#        'Foetal exposure during pregnancy', 'Fibromyalgia',
#        'Blood cholesterol abnormal', 'Glycosylated haemoglobin',
#        'Liver disorder', 'Hypothyroidism',
#        'Functional gastrointestinal disorder',
#        'Gastrointestinal motility disorder',
#        'Blood cholesterol decreased', 'Arthritis',
#        'Blood pressure increased', 'Blood triglycerides increased',
#        'Blood triglycerides abnormal', 'Liver transplant',
#        'Type I hyperlipidaemia', 'Body mass index',
#        'Hyperchylomicronaemia', 'Blood triglycerides decreased',
#        'Nutritional supplementation', 'Low density lipoprotein increased',
#        'Menopause', 'Hidradenitis', 'Migraine', 'Blood insulin increased',
#        'Endocrine disorder', 'Dolichocolon', 'Intestinal obstruction',
#        'Toxicity to various agents', 'Diet failure',
#        'Product use in unapproved indication', 'Proctitis ulcerative'],
#       dtype=object)

# %%
##unique values for dsg_drug_seq
ten_yrs_data['dsg_drug_seq'].unique()
# Out:
# array([ 17.,  nan,   1.,   9.,  35.,   2.,   3.,   4.,   5.,   8.,   6.,
#         11.,  26.,  10.,  18.,  16.,   7.,  14.,  13.,  25.,  19.,  31.,
#         21.,  39.,  33.,  22.,  12.,  20.,  23.,  15.,  24.,  32.,  50.,
#         30.,  34.,  53.,  43.,  44.,  45.,  28.,  42.,  46.,  49., 129.,
#        166.,  97.,  54., 182., 183.,  36.,  88.,  96.])

# %% [markdown]
# **Imputation**

# %%
##fill the missing values

##copy the dataframe
ten_yrs_data_cpy = ten_yrs_data.copy()

##fill missing values of age_cod col with Unknown
ten_yrs_data_cpy['age_cod'].fillna('Unknown', inplace = True)

##fill missing values of sex col with Unknown
ten_yrs_data_cpy['sex'].fillna('Unknown', inplace = True)

##fill missing values of the outc_cod col with Unknown
ten_yrs_data_cpy['outc_cod'].fillna('Unkown', inplace = True)

##fill missing values of route col with Unknown
ten_yrs_data_cpy['route'].fillna('Unknown', inplace = True)

##fill missing values of dose_vbm col with UNK
ten_yrs_data_cpy['dose_vbm'].fillna('UNK', inplace = True)

##fill missing values of dechal col with Unknown
ten_yrs_data_cpy['dechal'].fillna('U', inplace = True)

##fill missing values of lot_num col with Unknown
ten_yrs_data_cpy['lot_num'].fillna('UNKNOWN', inplace = True)

##fill missing values of nda_num col with mode value
ten_yrs_data_cpy['nda_num'] = ten_yrs_data_cpy['nda_num'].fillna(ten_yrs_data_cpy['nda_num'].mode()[0])

##fill missing values of dose_form col with Unknown
ten_yrs_data_cpy['dose_form'].fillna('Unknown', inplace = True)

##fill missing values of age col with mean age
ten_yrs_data_cpy['age'] = ten_yrs_data_cpy['age'].fillna(ten_yrs_data_cpy['age'].mean())

##fill missing values of indi_drug_seq col with Unknown
ten_yrs_data_cpy['indi_drug_seq'].fillna('Unknown', inplace = True)

##fill missing values of indi_pt col with Unknown
ten_yrs_data_cpy['indi_pt'].fillna('Unknown', inplace = True)

##fill missing values of dsg_drug_seq col with Unknown
ten_yrs_data_cpy['dsg_drug_seq'].fillna('Unknown', inplace = True)
# Out:
# /tmp/ipython-input-950944080.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ten_yrs_data_cpy['age_cod'].fillna('Unknown', inplace = True)
# /tmp/ipython-input-950944080.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ten_yrs_data_cpy['sex'].fillna('Unknown', inplace = True)
# /tmp/ipython-input-950944080.py:13: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ten_yrs_data_cpy['outc_cod'].fillna('Unkown', inplace = True)
# /tmp/ipython-input-950944080.py:16: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ten_yrs_data_cpy['route'].fillna('Unknown', inplace = True)
# /tmp/ipython-input-950944080.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ten_yrs_data_cpy['dose_vbm'].fillna('UNK', inplace = True)
# /tmp/ipython-input-950944080.py:22: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ten_yrs_data_cpy['dechal'].fillna('U', inplace = True)
# /tmp/ipython-input-950944080.py:25: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ten_yrs_data_cpy['lot_num'].fillna('UNKNOWN', inplace = True)
# /tmp/ipython-input-950944080.py:31: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ten_yrs_data_cpy['dose_form'].fillna('Unknown', inplace = True)
# /tmp/ipython-input-950944080.py:37: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ten_yrs_data_cpy['indi_drug_seq'].fillna('Unknown', inplace = True)
# /tmp/ipython-input-950944080.py:37: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Unknown' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   ten_yrs_data_cpy['indi_drug_seq'].fillna('Unknown', inplace = True)
# /tmp/ipython-input-950944080.py:40: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ten_yrs_data_cpy['indi_pt'].fillna('Unknown', inplace = True)
# /tmp/ipython-input-950944080.py:43: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ten_yrs_data_cpy['dsg_drug_seq'].fillna('Unknown', inplace = True)
# /tmp/ipython-input-950944080.py:43: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Unknown' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   ten_yrs_data_cpy['dsg_drug_seq'].fillna('Unknown', inplace = True)

# %%
##null value counts
print(ten_yrs_data_cpy.isnull().sum())
# Out:
# primaryid           0
# caseid              0
# caseversion         0
# i_f_code            0
# mfr_dt              0
# init_fda_dt         0
# fda_dt              0
# rept_cod            0
# mfr_num             0
# mfr_sndr            0
# age                 0
# age_cod             0
# sex                 0
# e_sub               0
# rept_dt             0
# occp_cod            0
# reporter_country    0
# occr_country        0
# outc_cod            0
# pt                  0
# drug_seq            0
# role_cod            0
# drugname            0
# prod_ai             0
# val_vbm             0
# route               0
# dose_vbm            0
# dechal              0
# lot_num             0
# nda_num             0
# dose_form           0
# indi_drug_seq       0
# indi_pt             0
# dsg_drug_seq        0
# dtype: int64

# %%
##visualise missing values
msno.matrix(ten_yrs_data_cpy)
plt.show()

# %%
##convert age to same unit -> year

##mapping function
def convert_age(row):

    if row['age_cod'] == 'YR': ##age is in years

        ##return yrs
        return row['age']

    elif row['age_cod'] == 'MON': ##age is in months

        ##convert months to yrs
        return row['age']/12

    elif row['age_cod'] == 'WK': ##age is in weeks

        ##convert weeks to years
        return row['age']/52

    elif row['age_cod'] == 'DY': ##age is in days

        ##convert days to yrs
        return row['age']/365

    elif row['age_cod'] == 'DEC': ##age is in decade

        ##convert decade to yrs
        return row['age']*10

    else:
        return None

##apply the mapping function to df
ten_yrs_data_cpy['age_in_yrs'] = ten_yrs_data_cpy.apply(convert_age, axis = 1)

# %%
##display head
ten_yrs_data_cpy.head()
# Out:
#     primaryid    caseid  caseversion i_f_code     mfr_dt init_fda_dt  \
# 1  1314962521  13149625           21        F 2020-02-18  2017-01-25
# 2  1352573513  13525735           13        F 2019-12-23  2017-05-09
# 3   147306292  14730629            2        F 2020-02-27  2018-04-06
# 5   151265324  15126532            4        F 2020-01-02  2018-07-10
# 6   152211425  15221142            5        F 2020-01-22  2018-07-31
#
#       fda_dt rept_cod                           mfr_num             mfr_sndr  \
# 1 2020-03-02      EXP    CA-CELLTRION INC.-2017CA000780            CELLTRION
# 2 2020-01-06      EXP                  CA-ROCHE-1931885                ROCHE
# 3 2020-03-09      EXP                GB-NOVOPROD-593576         NOVO NORDISK
# 5 2020-01-07      EXP             US-JNJFOC-20180709795  JOHNSON AND JOHNSON
# 6 2020-01-30      EXP  PT-AUROBINDO-AUR-APL-2018-038679            AUROBINDO
#
#    ...         route                   dose_vbm dechal  lot_num   nda_num  \
# 1  ...       Unknown                UNK, 1X/DAY      U  UNKNOWN  206321.0
# 2  ...       Unknown                        UNK      U  UNKNOWN  206321.0
# 3  ...  Subcutaneous                     1.8 MG      U  UNKNOWN   22341.0
# 5  ...       Unknown                        UNK      D  UNKNOWN  206321.0
# 6  ...          Oral  100 MILLIGRAM, ONCE A DAY      Y  UNKNOWN  206321.0
#
#                 dose_form indi_drug_seq                              indi_pt  \
# 1                 Unknown       Unknown                              Unknown
# 2                 Unknown          21.0  Product used for unknown indication
# 3  SOLUTION FOR INJECTION           1.0                    Diabetes mellitus
# 5                 Unknown           4.0  Product used for unknown indication
# 6                 CAPSULE          17.0                     Weight decreased
#
#   dsg_drug_seq age_in_yrs
# 1         17.0        NaN
# 2      Unknown       44.0
# 3          1.0       63.0
# 5      Unknown       70.0
# 6      Unknown       48.0
#
# [5 rows x 35 columns]

# %%
##save the cleaned data to csv file

##file path
csv_file = "/content/drive/MyDrive/Ten_years_data_cleand.csv"

##save the file
ten_yrs_data_cpy.to_csv(csv_file, index = False)
print(f"Cleaned data save to {csv_file} path successfully.")

# %%
##checking for possible duplicates

# Make a temporary copy with list columns converted to strings
df_temp = ten_yrs_data_cpy.copy()

# Convert all list-type columns to strings
for col in df_temp.columns:
    if df_temp[col].apply(lambda x: isinstance(x, list)).any():
        df_temp[col] = df_temp[col].apply(str)

# Now check for duplicates
print(df_temp.duplicated().sum())
# Out:
# 0

# %%
#smoothed age distribution KDE plot

# Ensure age_in_yrs is numeric, coercing errors to NaN
ten_yrs_data_cpy['age_in_yrs'] = pd.to_numeric(ten_yrs_data_cpy['age_in_yrs'], errors='coerce')

# Drop any NaNs
age_cleaned = ten_yrs_data_cpy['age_in_yrs'].dropna()
age_cleaned = age_cleaned[np.isfinite(age_cleaned)]

plt.figure(figsize = (8, 5))
sns.kdeplot(x = age_cleaned, fill = True, color = 'red')
plt.xlabel('Age')
plt.ylabel('Density')
plt.title('Age density distribution')

plt.grid(False)
plt.show()

# %%
##check for possible outliers

##Boxplot for outlier detection
plt.figure(figsize = (8, 5))
sns.boxplot(x = ten_yrs_data_cpy['age_in_yrs'].dropna())
plt.title('Age Distribution - Box Plot')

plt.grid(False)
plt.show()

# %%
min(ten_yrs_data_cpy['age_in_yrs'].dropna())
# Out:
# 0.0

# %%
max(ten_yrs_data_cpy['age_in_yrs'].dropna())
# Out:
# 104.0

# %%
ten_yrs_data_cpy.isnull().sum()
# Out:
# primaryid              0
# caseid                 0
# caseversion            0
# i_f_code               0
# mfr_dt                 0
# init_fda_dt            0
# fda_dt                 0
# rept_cod               0
# mfr_num                0
# mfr_sndr               0
# age                    0
# age_cod                0
# sex                    0
# e_sub                  0
# rept_dt                0
# occp_cod               0
# reporter_country       0
# occr_country           0
# outc_cod               0
# pt                     0
# drug_seq               0
# role_cod               0
# drugname               0
# prod_ai                0
# val_vbm                0
# route                  0
# dose_vbm               0
# dechal                 0
# lot_num                0
# nda_num                0
# dose_form              0
# indi_drug_seq          0
# indi_pt                0
# dsg_drug_seq           0
# age_in_yrs          8423
# dtype: int64

# %%
###The age_in_yrs column has 8423 missing values which comes
###from the cells with unknown values for the age column.
###Then we need to convert them to unknown
ten_yrs_data_cpy['age_in_yrs'].fillna("Unknown", inplace=True)

ten_yrs_data_cpy.isnull().sum()
# Out:
# /tmp/ipython-input-2156303394.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ten_yrs_data_cpy['age_in_yrs'].fillna("Unknown", inplace=True)
# /tmp/ipython-input-2156303394.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Unknown' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   ten_yrs_data_cpy['age_in_yrs'].fillna("Unknown", inplace=True)
# primaryid           0
# caseid              0
# caseversion         0
# i_f_code            0
# mfr_dt              0
# init_fda_dt         0
# fda_dt              0
# rept_cod            0
# mfr_num             0
# mfr_sndr            0
# age                 0
# age_cod             0
# sex                 0
# e_sub               0
# rept_dt             0
# occp_cod            0
# reporter_country    0
# occr_country        0
# outc_cod            0
# pt                  0
# drug_seq            0
# role_cod            0
# drugname            0
# prod_ai             0
# val_vbm             0
# route               0
# dose_vbm            0
# dechal              0
# lot_num             0
# nda_num             0
# dose_form           0
# indi_drug_seq       0
# indi_pt             0
# dsg_drug_seq        0
# age_in_yrs          0
# dtype: int64

# %%
ten_yrs_data_cpy.head()
# Out:
#     primaryid    caseid  caseversion i_f_code     mfr_dt init_fda_dt  \
# 1  1314962521  13149625           21        F 2020-02-18  2017-01-25
# 2  1352573513  13525735           13        F 2019-12-23  2017-05-09
# 3   147306292  14730629            2        F 2020-02-27  2018-04-06
# 5   151265324  15126532            4        F 2020-01-02  2018-07-10
# 6   152211425  15221142            5        F 2020-01-22  2018-07-31
#
#       fda_dt rept_cod                           mfr_num             mfr_sndr  \
# 1 2020-03-02      EXP    CA-CELLTRION INC.-2017CA000780            CELLTRION
# 2 2020-01-06      EXP                  CA-ROCHE-1931885                ROCHE
# 3 2020-03-09      EXP                GB-NOVOPROD-593576         NOVO NORDISK
# 5 2020-01-07      EXP             US-JNJFOC-20180709795  JOHNSON AND JOHNSON
# 6 2020-01-30      EXP  PT-AUROBINDO-AUR-APL-2018-038679            AUROBINDO
#
#    ...         route                   dose_vbm dechal  lot_num   nda_num  \
# 1  ...       Unknown                UNK, 1X/DAY      U  UNKNOWN  206321.0
# 2  ...       Unknown                        UNK      U  UNKNOWN  206321.0
# 3  ...  Subcutaneous                     1.8 MG      U  UNKNOWN   22341.0
# 5  ...       Unknown                        UNK      D  UNKNOWN  206321.0
# 6  ...          Oral  100 MILLIGRAM, ONCE A DAY      Y  UNKNOWN  206321.0
#
#                 dose_form indi_drug_seq                              indi_pt  \
# 1                 Unknown       Unknown                              Unknown
# 2                 Unknown          21.0  Product used for unknown indication
# 3  SOLUTION FOR INJECTION           1.0                    Diabetes mellitus
# 5                 Unknown           4.0  Product used for unknown indication
# 6                 CAPSULE          17.0                     Weight decreased
#
#   dsg_drug_seq age_in_yrs
# 1         17.0    Unknown
# 2      Unknown       44.0
# 3          1.0       63.0
# 5      Unknown       70.0
# 6      Unknown       48.0
#
# [5 rows x 35 columns]

# %%
##convert the codes in our data to meaningful descriptions
##i_f_code - code for initial or follow-up status of report
##i_f_code: 'I' -> 'Initial', 'F' -> 'Follow-up'

new_values = {
    "F": "Follow-up",
    "I": "Initial"
}

ten_yrs_data_cpy["i_f_code"] = ten_yrs_data_cpy['i_f_code'].replace(new_values)
ten_yrs_data_cpy.head()
# Out:
#     primaryid    caseid  caseversion   i_f_code     mfr_dt init_fda_dt  \
# 1  1314962521  13149625           21  Follow-up 2020-02-18  2017-01-25
# 2  1352573513  13525735           13  Follow-up 2019-12-23  2017-05-09
# 3   147306292  14730629            2  Follow-up 2020-02-27  2018-04-06
# 5   151265324  15126532            4  Follow-up 2020-01-02  2018-07-10
# 6   152211425  15221142            5  Follow-up 2020-01-22  2018-07-31
#
#       fda_dt rept_cod                           mfr_num             mfr_sndr  \
# 1 2020-03-02      EXP    CA-CELLTRION INC.-2017CA000780            CELLTRION
# 2 2020-01-06      EXP                  CA-ROCHE-1931885                ROCHE
# 3 2020-03-09      EXP                GB-NOVOPROD-593576         NOVO NORDISK
# 5 2020-01-07      EXP             US-JNJFOC-20180709795  JOHNSON AND JOHNSON
# 6 2020-01-30      EXP  PT-AUROBINDO-AUR-APL-2018-038679            AUROBINDO
#
#    ...         route                   dose_vbm dechal  lot_num   nda_num  \
# 1  ...       Unknown                UNK, 1X/DAY      U  UNKNOWN  206321.0
# 2  ...       Unknown                        UNK      U  UNKNOWN  206321.0
# 3  ...  Subcutaneous                     1.8 MG      U  UNKNOWN   22341.0
# 5  ...       Unknown                        UNK      D  UNKNOWN  206321.0
# 6  ...          Oral  100 MILLIGRAM, ONCE A DAY      Y  UNKNOWN  206321.0
#
#                 dose_form indi_drug_seq                              indi_pt  \
# 1                 Unknown       Unknown                              Unknown
# 2                 Unknown          21.0  Product used for unknown indication
# 3  SOLUTION FOR INJECTION           1.0                    Diabetes mellitus
# 5                 Unknown           4.0  Product used for unknown indication
# 6                 CAPSULE          17.0                     Weight decreased
#
#   dsg_drug_seq age_in_yrs
# 1         17.0    Unknown
# 2      Unknown       44.0
# 3          1.0       63.0
# 5      Unknown       70.0
# 6      Unknown       48.0
#
# [5 rows x 35 columns]

# %%
##rept_cod - code for the type of report submited
##rept_cod: 'EXP' -> 'Expedited', 'PER' -> 'Periodic(Non-Expedited)', 'DIR' -> 'Direct'

ten_yrs_data_cpy['rept_cod'].unique()
# Out:
# array(['EXP', 'PER', '30DAY', '5DAY'], dtype=object)

# %%
rept_values = {"EXP": "Expedited",
               "PER": "Periodic",
               "30DAY": "30 Days",
               "5DAY": "5 Days"}
ten_yrs_data_cpy['rept_cod'] = ten_yrs_data_cpy['rept_cod'].replace(rept_values)

ten_yrs_data_cpy['rept_cod'].unique()
# Out:
# array(['Expedited', 'Periodic', '30 Days', '5 Days'], dtype=object)

# %%
##age_cod - unit abbreviation for patient's age
##age_cod: 'DEC' -> 'Decade', 'YR' -> 'Year', 'MON' -> 'Month',
##'WK' -> 'Week', 'DY' -> 'Day', 'HR' -> 'Hour'

ten_yrs_data_cpy['age_cod'].unique()
# Out:
# array(['Unknown', 'YR', 'MON', 'DY', 'DEC', 'WK'], dtype=object)

# %%
age_cod_vals = {
    'Unknown': 'Unknown',
    'YR': 'Year',
    'MON': 'Month',
    'DY': 'Day',
    'DEC': 'Decade',
    'WK': 'Week'
}

ten_yrs_data_cpy['age_cod'] = ten_yrs_data_cpy['age_cod'].replace(age_cod_vals)
ten_yrs_data_cpy['age_cod'].unique()
# Out:
# array(['Unknown', 'Year', 'Month', 'Day', 'Decade', 'Week'], dtype=object)

# %%
##e_sub - whether the report was submitted under the electronic subs procedure
##e_sub: 'Y'-> 'Yes', 'N' -> 'No'

ten_yrs_data_cpy['e_sub'].unique()
# Out:
# array(['Y'], dtype=object)

# %%
esub_vals = {'Y': 'Yes', 'N': 'No'}

ten_yrs_data_cpy['e_sub'] = ten_yrs_data_cpy['e_sub'].replace(esub_vals)

ten_yrs_data_cpy['e_sub'].unique()
# Out:
# array(['Yes'], dtype=object)

# %%
##occp_cod - reporter's type of occupation in the latest version of a case
##occp_cod: 'MD' -> 'Physician', 'PH' -> 'Pharmacist', 'OT' -> 'Other health-professional',
##'LW' -> 'Lawyer', 'CN' -> 'Consumer'

ten_yrs_data_cpy['occp_cod'].unique()
# Out:
# array(['HP', 'CN', 'MD', 'PH', 'LW', 'OT'], dtype=object)

# %%
occp_vals = {
    'HP': 'Pharmacist',
    'PH': 'Pharmacist',
    'MD': 'Physician',
    'OT': 'Other health-professional',
    'LW': 'Lawyer',
    'CN': 'Consumer'
}
##replace codes with full names
ten_yrs_data_cpy['occp_cod'] = ten_yrs_data_cpy['occp_cod'].replace(occp_vals)

ten_yrs_data_cpy['occp_cod'].unique()
# Out:
# array(['Pharmacist', 'Consumer', 'Physician', 'Lawyer',
#        'Other health-professional'], dtype=object)

# %%
##reporter_country - the country of the reporter in the latest version of a case
##assign names to country codes
rept_country_vals = {
   'US': 'United States', 'CA': 'Canada', 'GB': 'United Kingdom', 'BR': 'Brazil',
   'ES': 'Spain', 'MX': 'Mexico', 'IR': 'Iran', 'PT': "Portugal", "AU": 'Australia',
   'AR': "Argentina", 'IL': 'Israel', 'DE': 'Germany', 'CO': 'Colombia',
   'RU': 'Russia', 'KR': 'South Korea', 'NL': 'Netherlands', 'TH': 'Thailand',
   'COUNTRY NOT SPECIFIED': 'Unknown', 'TR': 'Turkey',
   'DK': 'Denmark', 'LB': 'Lebanon', 'CL': 'Chile',
   'FR': 'France', 'IT': 'Italy', 'HR': 'Croatia',
   'CN': 'China', 'AT': 'Austria', 'NO': 'Norway',
   'JP': 'Japan', 'SA': 'Saudi Arabia', 'EC': 'Ecuador',
   'SE': 'Sweden', 'IE': 'Ireland', 'CZ': 'Czech Republic',
   'MT': 'Malta', 'SI': 'Slovenia', 'GR': 'Greece',
   'EG': 'Egypt', 'PH': 'Philippines', 'IN': 'India',
   'QA': 'Qatar', 'PK': 'Pakistan', 'FI': 'Finland',
   'AE': 'United Arab Emirates', 'TW': 'Taiwan', 'IS': 'Iceland',
   'BE': 'Belgium', 'NZ': 'New Zealand', 'ZA': 'South Africa',
   'MY': 'Malaysia', 'PL': 'Poland', 'HU': 'Hungary',
   'JO': 'Jordan', 'EE': 'Estonia', 'LU': 'Luxembourg',
   'CR': 'Costa Rica', 'PE': 'Peru', 'BG': 'Bulgaria',
   'RS': 'Serbia', 'RO': 'Romania', 'SY': 'Syria',
   'KW': 'Kuwait', 'SG': 'Singapore', 'SK': 'Slovakia',
   'VN': 'Vietnam', 'UA': 'Ukraine', 'BH': 'Bahrain',
   'DO': 'Dominican Republic', 'PR': 'Puerto Rico', 'ID': 'Indonesia',
   'UY': 'Uruguay', 'LV': 'Latvia', 'TT': 'Trinidad and Tobago',
   'KZ': 'Kazakhstan', 'MM': 'Myanmar'

}

##replace the country codes
ten_yrs_data_cpy['reporter_country'] = ten_yrs_data_cpy['reporter_country'].replace(rept_country_vals)

ten_yrs_data_cpy['reporter_country'].unique()
# Out:
# array(['Canada', 'United Kingdom', 'United States', 'Portugal', 'Brazil',
#        'Spain', 'Mexico', 'Iran', 'Australia', 'Argentina', 'Israel',
#        'Germany', 'Colombia', 'Russia', 'South Korea', 'Netherlands',
#        'Thailand', 'Unknown', 'Turkey', 'Denmark', 'Lebanon', 'Chile',
#        'France', 'Italy', 'Croatia', 'China', 'CH', 'Austria', 'Norway',
#        'Japan', 'Saudi Arabia', 'Ecuador', 'Sweden', 'Ireland',
#        'Czech Republic', 'Malta', 'Slovenia', 'Greece', 'Egypt',
#        'Philippines', 'India', 'Qatar', 'Pakistan', 'Finland',
#        'United Arab Emirates', 'Taiwan', 'Iceland', 'Belgium',
#        'New Zealand', 'South Africa', 'Malaysia', 'Poland', 'Hungary',
#        'Jordan', 'Estonia', 'Luxembourg', 'Costa Rica', 'Peru',
#        'Bulgaria', 'Serbia', 'Romania', 'Syria', 'Kuwait', 'Singapore',
#        'Slovakia', 'Vietnam', 'Ukraine', 'Bahrain', 'Dominican Republic',
#        'Puerto Rico', 'Indonesia', 'Uruguay', 'Latvia',
#        'Trinidad and Tobago', 'Kazakhstan', 'Myanmar'], dtype=object)

# %%
##occr_country -  the country where the event occurred

ten_yrs_data_cpy['occr_country'].unique()
# Out:
# array(['CA', 'GB', 'US', 'PT', 'BR', 'ES', 'MX', 'IR', 'AU', 'AR', 'IL',
#        'DE', 'CO', 'RU', 'KR', 'TH', 'SG', 'TR', 'DK', 'LB', 'CL', 'FR',
#        'IT', 'HR', 'CN', 'CH', 'AT', 'NO', 'JP', 'SA', 'EC', 'SE', 'IE',
#        'CZ', 'MT', 'SI', 'NL', 'GR', 'EG', 'PH', 'QA', 'AE', 'TW', 'IS',
#        'BE', 'IN', 'NZ', 'ZA', 'MY', 'PL', 'FI', 'HU', 'PK', 'JO', 'EE',
#        'LU', 'CR', 'PE', 'BG', 'RS', 'RO', 'SY', 'KW', 'SK', 'VN', 'UA',
#        'BH', 'DO', 'ID', 'UY', 'LV', 'TT', 'NG', 'KZ', 'LK', 'HK', 'MM'],
#       dtype=object)

# %%
##replace the codes
ten_yrs_data_cpy['occr_country'] = ten_yrs_data_cpy['occr_country'].replace(rept_country_vals)
ten_yrs_data_cpy['occr_country'].unique()
# Out:
# array(['Canada', 'United Kingdom', 'United States', 'Portugal', 'Brazil',
#        'Spain', 'Mexico', 'Iran', 'Australia', 'Argentina', 'Israel',
#        'Germany', 'Colombia', 'Russia', 'South Korea', 'Thailand',
#        'Singapore', 'Turkey', 'Denmark', 'Lebanon', 'Chile', 'France',
#        'Italy', 'Croatia', 'China', 'CH', 'Austria', 'Norway', 'Japan',
#        'Saudi Arabia', 'Ecuador', 'Sweden', 'Ireland', 'Czech Republic',
#        'Malta', 'Slovenia', 'Netherlands', 'Greece', 'Egypt',
#        'Philippines', 'Qatar', 'United Arab Emirates', 'Taiwan',
#        'Iceland', 'Belgium', 'India', 'New Zealand', 'South Africa',
#        'Malaysia', 'Poland', 'Finland', 'Hungary', 'Pakistan', 'Jordan',
#        'Estonia', 'Luxembourg', 'Costa Rica', 'Peru', 'Bulgaria',
#        'Serbia', 'Romania', 'Syria', 'Kuwait', 'Slovakia', 'Vietnam',
#        'Ukraine', 'Bahrain', 'Dominican Republic', 'Indonesia', 'Uruguay',
#        'Latvia', 'Trinidad and Tobago', 'NG', 'Kazakhstan', 'LK', 'HK',
#        'Myanmar'], dtype=object)

# %%
occr_cnt_vals = {
    'CH': 'Switzerland',
    'NG': 'Nigeria',
    'LK': 'Sri Lanka',
    'HK': 'Hong Kong'
}

#replace the remaining codes
ten_yrs_data_cpy['occr_country'] = ten_yrs_data_cpy['occr_country'].replace(occr_cnt_vals)
ten_yrs_data_cpy['occr_country'].unique()
# Out:
# array(['Canada', 'United Kingdom', 'United States', 'Portugal', 'Brazil',
#        'Spain', 'Mexico', 'Iran', 'Australia', 'Argentina', 'Israel',
#        'Germany', 'Colombia', 'Russia', 'South Korea', 'Thailand',
#        'Singapore', 'Turkey', 'Denmark', 'Lebanon', 'Chile', 'France',
#        'Italy', 'Croatia', 'China', 'Switzerland', 'Austria', 'Norway',
#        'Japan', 'Saudi Arabia', 'Ecuador', 'Sweden', 'Ireland',
#        'Czech Republic', 'Malta', 'Slovenia', 'Netherlands', 'Greece',
#        'Egypt', 'Philippines', 'Qatar', 'United Arab Emirates', 'Taiwan',
#        'Iceland', 'Belgium', 'India', 'New Zealand', 'South Africa',
#        'Malaysia', 'Poland', 'Finland', 'Hungary', 'Pakistan', 'Jordan',
#        'Estonia', 'Luxembourg', 'Costa Rica', 'Peru', 'Bulgaria',
#        'Serbia', 'Romania', 'Syria', 'Kuwait', 'Slovakia', 'Vietnam',
#        'Ukraine', 'Bahrain', 'Dominican Republic', 'Indonesia', 'Uruguay',
#        'Latvia', 'Trinidad and Tobago', 'Nigeria', 'Kazakhstan',
#        'Sri Lanka', 'Hong Kong', 'Myanmar'], dtype=object)

# %%
##outc_cod - code for a patient outcome
##outc_cod: 'DE' -> 'Death', 'LT' -> 'Life threatening', 'HO' -> 'Hospitalization', 'DS' -> 'Disability'
##'CA' -> 'Congenital anomaly', 'RI' -> 'Required intervention to prevent impairment', 'OT' -> Other

outc_vals = {
    'DE': 'Death',
    'LT': 'Life threatening',
    'HO': 'Hospitalization',
    'DS': 'Disability',
    'CA': 'Congenital anomaly',
    'RI': 'Required intervention to prevent permanent imparment',
    'OT': 'Other'
}

##convert strings to real lists
def parse_if_list_like(val):
    # Only parse if it's a string starting and ending with brackets
    if isinstance(val, str) and val.strip().startswith('[') and val.strip().endswith(']'):
        try:
            parsed = ast.literal_eval(val)
            if isinstance(parsed, list):
                return parsed
        except (ValueError, SyntaxError):
            pass
    return val  # Return original if not list-like

ten_yrs_data_cpy['outc_cod'] = ten_yrs_data_cpy['outc_cod'].apply(parse_if_list_like)

def replace_items(val):
    if isinstance(val, list):
        return [outc_vals.get(item, item) for item in val]
    return val  # leave strings like 'Unknown' unchanged
ten_yrs_data_cpy['outc_cod'] = ten_yrs_data_cpy['outc_cod'].apply(replace_items)

# %%
ten_yrs_data_cpy['outc_cod'].head(6)
# Out:
# 1                                       [Other]
# 2                                       [Other]
# 3    [Death, Hospitalization, Life threatening]
# 5                      [Death, Hospitalization]
# 6    [Life threatening, Hospitalization, Other]
# 7                                       [Other]
# Name: outc_cod, dtype: object

# %%
##role_cod - code for drug's reported role in event
##role_code: 'PS' -> 'primary suspect drug', 'SS' -> 'Secondary suspect drug',
##'C' -> 'Concomitant', 'I' -> 'Interacting'

rolec_vals = {
    'PS': 'Primary suspect drug',
    'SS': 'Secondary suspect drug',
    'C': 'Concomitant',
    'I': 'Interacting'
}
##replace the codes
ten_yrs_data_cpy['role_cod'] = ten_yrs_data_cpy['role_cod'].replace(rolec_vals)

ten_yrs_data_cpy['role_cod'].unique()
# Out:
# array(['Concomitant', 'Primary suspect drug', 'Secondary suspect drug',
#        'Interacting'], dtype=object)

# %%
##dechal - dechallenge code, indicating if reaction abated when drug therapy was stopped
##dechal: 'Y' -> 'Positive dechallenge', 'N' -> 'Negative dechallenge', 'U' -> 'Unknown',
##'D' -> 'Does not apply'

dechal_vals = {
    'Y': 'Positive dechallenge',
    'N': 'Negative dechallenge',
    'U': 'Unknown',
    'D': 'Does not apply'
}
##replace the codes
ten_yrs_data_cpy['dechal'] = ten_yrs_data_cpy['dechal'].replace(dechal_vals)
ten_yrs_data_cpy['dechal'].unique()
# Out:
# array(['Unknown', 'Does not apply', 'Positive dechallenge',
#        'Negative dechallenge'], dtype=object)

# %%
sex_vals = {
    'M': 'Male',
    'F': 'Female'
}

##replace M -> Male and  F -> Felmale
ten_yrs_data_cpy['sex'] = ten_yrs_data_cpy['sex'].replace(sex_vals)
ten_yrs_data_cpy['sex'].unique()
# Out:
# array(['Unknown', 'Male', 'Female'], dtype=object)

# %%
##store the outc_cod in a long format
fears_data_exploded = ten_yrs_data_cpy.explode('outc_cod').reset_index(drop=True)
fears_data_exploded['outc_cod'].head(6)
# Out:
# 0               Other
# 1               Other
# 2               Death
# 3     Hospitalization
# 4    Life threatening
# 5               Death
# Name: outc_cod, dtype: object

# %%
fears_data_exploded['pt'] = fears_data_exploded['pt'].apply(ast.literal_eval)

##store pt in long format
fears_data_final = fears_data_exploded.explode('pt').reset_index(drop=True)

fears_data_final['pt'].head(6)
# Out:
# 0                                          Arthralgia
# 1                                           Back pain
# 2                            Blood pressure decreased
# 3                          Blood pressure fluctuation
# 4                            Blood pressure increased
# 5    Inappropriate schedule of product administration
# Name: pt, dtype: object

# %%
##convert the important column names to a meaningful names so that user queries for a QA bot
##can be easily used to get response from our data by using the col names to understand queries

##change 'pt' to 'adverse events'
fears_data_final = fears_data_final.rename(columns={'pt':'adverse_events'})
fears_data_final['adverse_events']
# Out:
# 0                         Arthralgia
# 1                          Back pain
# 2           Blood pressure decreased
# 3         Blood pressure fluctuation
# 4           Blood pressure increased
#                      ...
# 101949              Drug interaction
# 101950                    Eructation
# 101951                       Fatigue
# 101952                      Headache
# 101953                        Nausea
# Name: adverse_events, Length: 101954, dtype: object

# %%
##save the cleaned data to csv file

##file path
csv_file = "/content/drive/MyDrive/faers_data_cleand.csv"

##save the file
fears_data_final.to_csv(csv_file, index = False)
print(f"Cleaned data save to {csv_file} path successfully.")
