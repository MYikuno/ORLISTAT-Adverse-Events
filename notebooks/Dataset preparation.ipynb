# %%
##import libraries
import pandas as pd
import numpy as np
import os
import glob
from functools import reduce
import missingno as msno
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
import ast
import plotly.express as px

# %%
##path to our dataset
root_path = 'C:\\Users\\mulug\\OneDrive\\Documents\\Datasets\\'

# %%
def data_extraction(year, path, enc = 'utf-8'):
    
    ##list of target drug names
    target_drugs = ['xenical', 'alli', 'orlistat', 'liraglutide', 'saxenda']
    
    ##path to q1 ascii files
    q1_path = path + str(year)+"/faers_ascii_"+str(year)+"q1" + "/ASCII/"

    ##read demo data
    q1_DEMO = pd.read_csv(q1_path+f'DEMO{year%100}Q1.txt', delimiter = '$', dtype = str, encoding = enc)

    ##read drug data
    q1_DRUG = pd.read_csv(q1_path+f'DRUG{year%100}Q1.txt', delimiter = '$', dtype = str, encoding = enc)

    ##read indication data
    q1_INDI = pd.read_csv(q1_path+f'INDI{year%100}Q1.txt', delimiter = '$', dtype = str, encoding = enc)

    ##read outcome data
    q1_OUTC = pd.read_csv(q1_path+f'OUTC{year%100}Q1.txt', delimiter = '$', dtype = str, encoding = enc)

    ##read reaction data
    q1_REAC = pd.read_csv(q1_path+f'REAC{year%100}Q1.txt', delimiter = '$', dtype = str, encoding = enc)
    
    ##read therapy data
    q1_THER = pd.read_csv(q1_path+f'THER{year%100}Q1.txt', delimiter = '$', dtype = str, encoding = enc)
    
    #DEMO data copy
    merged_df1 = q1_DEMO.copy()
    
    ##aggregate multiple outcomes per report into a list
    outcome_agg = q1_OUTC.groupby("primaryid")["outc_cod"].apply(list).reset_index()
    
    ##merge the aggregated outcome data into merged_df1
    merged_df1 = merged_df1.merge(outcome_agg, on = ['primaryid'], how = 'left')
    
    ##aggregate multiple reactions per report into a list
    reac_agg = q1_REAC.groupby("primaryid")["pt"].apply(list).reset_index()
    
    ##merge the aggregated reaction data to merged_df1
    merged_df1 = merged_df1.merge(reac_agg, on = ['primaryid'], how = 'left')
    
    ##filter the target drugs
    q1_DRUG_filtered = q1_DRUG.loc[q1_DRUG['drugname'].str.lower().isin(target_drugs)]


    # Merge drug with indication using primaryid, caseid and drug_seq ↔ indi_drug_seq
    drug_indi = q1_DRUG_filtered.merge(q1_INDI, left_on=["primaryid", "caseid", "drug_seq"], right_on=["primaryid", "caseid", "indi_drug_seq"], how="left")
    
    # Merge drug_indi with q1_THER using primaryid, caseid and drug_seq ↔ dsg_drug_seq
    drug_indi_ther = drug_indi.merge(q1_THER, left_on=["primaryid", "caseid", "drug_seq"], right_on=["primaryid", "caseid", "dsg_drug_seq"], how="left")
    
    ##merge the drug_indi_ther to merged_df1
    merged_df1 = merged_df1.merge(drug_indi_ther, on = ['primaryid', 'caseid'], how = 'inner')
    
    #######################
    
    ##path to q2 ascii files
    q2_path = path + str(year)+"/faers_ascii_"+str(year)+"q2" + "/ASCII/"

    ##read demo data
    q2_DEMO = pd.read_csv(q2_path+f'DEMO{year%100}Q2.txt', delimiter = '$', dtype = str, encoding = enc)

    ##read drug data
    q2_DRUG = pd.read_csv(q2_path+f'DRUG{year%100}Q2.txt', delimiter = '$', dtype = str, encoding = enc)

    ##read indication data
    q2_INDI = pd.read_csv(q2_path+f'INDI{year%100}Q2.txt', delimiter = '$', dtype = str, encoding = enc)

    ##read outcome data
    q2_OUTC = pd.read_csv(q2_path+f'OUTC{year%100}Q2.txt', delimiter = '$', dtype = str, encoding = enc)

    ##read reaction data
    q2_REAC = pd.read_csv(q2_path+f'REAC{year%100}Q2.txt', delimiter = '$', dtype = str, encoding = enc)
    
    ##read therapy data
    q2_THER = pd.read_csv(q2_path+f'THER{year%100}Q2.txt', delimiter = '$', dtype = str, encoding = enc)
    

    #DEMO data copy
    merged_df2 = q2_DEMO.copy()
    
    ##aggregate multiple outcomes per report into a list
    outcome_agg = q2_OUTC.groupby("primaryid")["outc_cod"].apply(list).reset_index()
    
    ##merge the aggregated outcome data into merged_df2
    merged_df2 = merged_df2.merge(outcome_agg, on = ['primaryid'], how = 'left')
    
    ##aggregate multiple reactions per report into a list
    reac_agg = q2_REAC.groupby("primaryid")["pt"].apply(list).reset_index()
    
    ##merge the aggregated reaction data to merged_df2
    merged_df2 = merged_df2.merge(reac_agg, on = ['primaryid'], how = 'left')
    
    ##filter the target drugs
    q2_DRUG_filtered = q2_DRUG.loc[q2_DRUG['drugname'].str.lower().isin(target_drugs)]


    # Merge drug with indication using primaryid, caseid and drug_seq ↔ indi_drug_seq
    drug_indi = q2_DRUG_filtered.merge(q2_INDI, left_on=["primaryid", "caseid", "drug_seq"], right_on=["primaryid", "caseid", "indi_drug_seq"], how="left")
    
    # Merge drug_indi with q2_THER using primaryid, caseid and drug_seq ↔ dsg_drug_seq
    drug_indi_ther = drug_indi.merge(q2_THER, left_on=["primaryid", "caseid", "drug_seq"], right_on=["primaryid", "caseid", "dsg_drug_seq"], how="left")
    
    ##merge the drug_indi_ther to merged_df2
    merged_df2 = merged_df2.merge(drug_indi_ther, on = ['primaryid', 'caseid'], how = 'inner')

    
    ########################
    
    ##path to q3 ascii files
    q3_path = path + str(year)+"/faers_ascii_"+str(year)+"q3" + "/ASCII/"

    ##read demo data
    q3_DEMO = pd.read_csv(q3_path+f'DEMO{year%100}Q3.txt', delimiter = '$', dtype = str, encoding = enc)

    ##read drug data
    q3_DRUG = pd.read_csv(q3_path+f'DRUG{year%100}Q3.txt', delimiter = '$', dtype = str, encoding = enc)

    ##read indication data
    q3_INDI = pd.read_csv(q3_path+f'INDI{year%100}Q3.txt', delimiter = '$', dtype = str, encoding = enc)

    ##read outcome data
    q3_OUTC = pd.read_csv(q3_path+f'OUTC{year%100}Q3.txt', delimiter = '$', dtype = str, encoding = enc)

    ##read reaction data
    q3_REAC = pd.read_csv(q3_path+f'REAC{year%100}Q3.txt', delimiter = '$', dtype = str, encoding = enc)
    
    ##read therapy data
    q3_THER = pd.read_csv(q3_path+f'THER{year%100}Q3.txt', delimiter = '$', dtype = str, encoding = enc)
    

    #DEMO data copy
    merged_df3 = q3_DEMO.copy()
    
    ##aggregate multiple outcomes per report into a list
    outcome_agg = q3_OUTC.groupby("primaryid")["outc_cod"].apply(list).reset_index()
    
    ##merge the aggregated outcome data into merged_df3
    merged_df3 = merged_df3.merge(outcome_agg, on = ['primaryid'], how = 'left')
    
    ##aggregate multiple reactions per report into a list
    reac_agg = q3_REAC.groupby("primaryid")["pt"].apply(list).reset_index()
    
    ##merge the aggregated reaction data to merged_df3
    merged_df3 = merged_df3.merge(reac_agg, on = ['primaryid'], how = 'left')
    
    ##filter the target drugs
    q3_DRUG_filtered = q3_DRUG.loc[q3_DRUG['drugname'].str.lower().isin(target_drugs)]


    # Merge drug with indication using primaryid, caseid and drug_seq ↔ indi_drug_seq
    drug_indi = q3_DRUG_filtered.merge(q3_INDI, left_on=["primaryid", "caseid", "drug_seq"], right_on=["primaryid", "caseid", "indi_drug_seq"], how="left")
    
    # Merge drug_indi with q3_THER using primaryid, caseid and drug_seq ↔ dsg_drug_seq
    drug_indi_ther = drug_indi.merge(q3_THER, left_on=["primaryid", "caseid", "drug_seq"], right_on=["primaryid", "caseid", "dsg_drug_seq"], how="left")
    
    ##merge the drug_indi_ther to merged_df3
    merged_df3 = merged_df3.merge(drug_indi_ther, on = ['primaryid', 'caseid'], how = 'inner')


    #######################
    
    ##path to q4 ascii files
    q4_path = path + str(year)+"/faers_ascii_"+str(year)+"Q4" + "/ASCII/"

    ##read demo data
    q4_DEMO = pd.read_csv(q4_path+f'DEMO{year%100}Q4.txt', delimiter = '$', dtype = str, encoding = enc)

    ##read drug data
    q4_DRUG = pd.read_csv(q4_path+f'DRUG{year%100}Q4.txt', delimiter = '$', dtype = str, encoding = enc)

    ##read indication data
    q4_INDI = pd.read_csv(q4_path+f'INDI{year%100}Q4.txt', delimiter = '$', dtype = str, encoding = enc)

    ##read outcome data
    q4_OUTC = pd.read_csv(q4_path+f'OUTC{year%100}Q4.txt', delimiter = '$', dtype = str, encoding = enc)

    ##read reaction data
    q4_REAC = pd.read_csv(q4_path+f'REAC{year%100}Q4.txt', delimiter = '$', dtype = str, encoding = enc)
    
    ##read therapy data
    q4_THER = pd.read_csv(q4_path+f'THER{year%100}Q4.txt', delimiter = '$', dtype = str, encoding = enc)
    

    #DEMO data copy
    merged_df4 = q4_DEMO.copy()
    
    ##aggregate multiple outcomes per report into a list
    outcome_agg = q4_OUTC.groupby("primaryid")["outc_cod"].apply(list).reset_index()
    
    ##merge the aggregated outcome data into merged_df4
    merged_df4 = merged_df4.merge(outcome_agg, on = ['primaryid'], how = 'left')
    
    ##aggregate multiple reactions per report into a list
    reac_agg = q4_REAC.groupby("primaryid")["pt"].apply(list).reset_index()
    
    ##merge the aggregated reaction data to merged_df4
    merged_df4 = merged_df4.merge(reac_agg, on = ['primaryid'], how = 'left')
    
    ##filter the target drugs
    q4_DRUG_filtered = q4_DRUG.loc[q4_DRUG['drugname'].str.lower().isin(target_drugs)]


    # Merge drug with indication using primaryid, caseid and drug_seq ↔ indi_drug_seq
    drug_indi = q4_DRUG_filtered.merge(q4_INDI, left_on=["primaryid", "caseid", "drug_seq"], right_on=["primaryid", "caseid", "indi_drug_seq"], how="left")
    
    # Merge drug_indi with q4_THER using primaryid, caseid and drug_seq ↔ dsg_drug_seq
    drug_indi_ther = drug_indi.merge(q4_THER, left_on=["primaryid", "caseid", "drug_seq"], right_on=["primaryid", "caseid", "dsg_drug_seq"], how="left")
    
    ##merge the drug_indi_ther to merged_df4
    merged_df4 = merged_df4.merge(drug_indi_ther, on = ['primaryid', 'caseid'], how = 'inner')

    ##return the full data for each year as list of 
    ##quarterly dfs
    return [merged_df1, merged_df2, merged_df3, merged_df4]

# %%
##yearly extracted data for 2024
dfs_2024 = data_extraction(2024, root_path)

##concatenate dfs
data_2024 = pd.concat(dfs_2024, ignore_index = True)

##display data
data_2024
# Out:
#        primaryid    caseid caseversion i_f_code  event_dt    mfr_dt  \
# 0     1131845744  11318457          44        F  20150101  20240125
# 1     1564086814  15640868          14        F       NaN  20240111
# 2     1564086814  15640868          14        F       NaN  20240111
# 3      157756714  15775671           4        F  20190101  20240205
# 4      168364652  16836465           2        F       NaN  20240305
# ...          ...       ...         ...      ...       ...       ...
# 1790   247864171  24786417           1        I  20240801  20241218
# 1791   247901862  24790186           2        F       NaN  20241226
# 1792   247912301  24791230           1        I  20241214  20241219
# 1793   247913931  24791393           1        I  20220201  20241220
# 1794   247914061  24791406           1        I  20241213  20241219
#
#      init_fda_dt    fda_dt rept_cod auth_num  ... dose_unit  \
# 0       20150729  20240206      EXP      NaN  ...       NaN
# 1       20181120  20240118      EXP      NaN  ...       NaN
# 2       20181120  20240118      EXP      NaN  ...       NaN
# 3       20181231  20240213      EXP      NaN  ...        MG
# 4       20190921  20240318      EXP      NaN  ...       NaN
# ...          ...       ...      ...      ...  ...       ...
# 1790    20241230  20241230      EXP      NaN  ...       NaN
# 1791    20241230  20241231      PER      NaN  ...       NaN
# 1792    20241230  20241230      EXP      NaN  ...        MG
# 1793    20241231  20241231      EXP      NaN  ...        MG
# 1794    20241231  20241231      EXP      NaN  ...        MG
#
#                    dose_form dose_freq indi_drug_seq  \
# 0                        NaN       NaN            50
# 1                    Capsule       NaN           119
# 2                    Capsule       NaN           NaN
# 3                        NaN        QD            20
# 4                        NaN       NaN            16
# ...                      ...       ...           ...
# 1790  Solution for injection       NaN             2
# 1791                 Capsule       NaN             1
# 1792  Solution for injection        QD             1
# 1793  Solution for injection        QD             1
# 1794  Solution for injection        QD             1
#
#                                   indi_pt dsg_drug_seq  start_dt    end_dt  \
# 0     Product used for unknown indication           50  20231201       NaN
# 1     Product used for unknown indication          NaN       NaN       NaN
# 2                                     NaN          NaN       NaN       NaN
# 3                        Weight decreased          NaN       NaN       NaN
# 4                       Diabetes mellitus          NaN       NaN       NaN
# ...                                   ...          ...       ...       ...
# 1790                       Weight control            2    202408       NaN
# 1791                     Weight decreased            1  20241224       NaN
# 1792                              Obesity          NaN       NaN       NaN
# 1793                              Obesity            1    202202    202203
# 1794  Product used for unknown indication            1  20241206  20241214
#
#       dur dur_cod
# 0     NaN     NaN
# 1     NaN     NaN
# 2     NaN     NaN
# 3     NaN     NaN
# 4     NaN     NaN
# ...   ...     ...
# 1790  NaN     NaN
# 1791  NaN     NaN
# 1792  NaN     NaN
# 1793  NaN     NaN
# 1794    8     DAY
#
# [1795 rows x 52 columns]

# %%
##yearly data for 2023   
dfs_2023 = data_extraction(2023, root_path)

##concatenate the returned dfs
data_2023 = pd.concat(dfs_2023, ignore_index = True)

##display data
data_2023
# Out:
#        primaryid    caseid caseversion i_f_code  event_dt    mfr_dt  \
# 0      111834804  11183480           4        F  20090401  20230126
# 1     1327603118  13276031          18        F       NaN  20230110
# 2      148792524  14879252           4        F       NaN  20230104
# 3     1522229623  15222296          23        F  20180101  20221230
# 4      162103223  16210322           3        F       NaN  20221221
# ...          ...       ...         ...      ...       ...       ...
# 1905   233450431  23345043           1        I  20231210  20231219
# 1906   233455541  23345554           1        I       NaN  20231204
# 1907   233511921  23351192           1        I  20230731  20231215
# 1908   233517301  23351730           1        I  20210101  20231218
# 1909   233571061  23357106           1        I  20210701  20231230
#
#      init_fda_dt    fda_dt rept_cod auth_num  ... dose_unit  \
# 0       20150612  20230207      EXP      NaN  ...       NaN
# 1       20170228  20230113      EXP      NaN  ...       NaN
# 2       20180511  20230106      EXP      NaN  ...       NaN
# 3       20180731  20230106      EXP      NaN  ...       NaN
# 4       20190418  20230104      EXP      NaN  ...       NaN
# ...          ...       ...      ...      ...  ...       ...
# 1905    20231228  20231228      EXP      NaN  ...       NaN
# 1906    20231228  20231228      EXP      NaN  ...        MG
# 1907    20231229  20231229      EXP      NaN  ...       NaN
# 1908    20231229  20231229      EXP      NaN  ...       NaN
# 1909    20231230  20231230      DIR   686120  ...       NaN
#
#                    dose_form dose_freq indi_drug_seq  \
# 0                        NaN       NaN             2
# 1                    Capsule       NaN            72
# 2                        NaN       NaN           NaN
# 3                        NaN       NaN           NaN
# 4                        NaN       NaN            21
# ...                      ...       ...           ...
# 1905                 Capsule       NaN             1
# 1906                     NaN        QD             2
# 1907  Solution for injection       NaN             1
# 1908  Solution for injection       NaN             1
# 1909                     NaN       NaN             1
#
#                                   indi_pt dsg_drug_seq  start_dt    end_dt  \
# 0                                 Obesity            2    200903    200906
# 1     Product used for unknown indication          NaN       NaN       NaN
# 2                                     NaN          NaN       NaN       NaN
# 3                                     NaN          NaN       NaN       NaN
# 4     Product used for unknown indication          NaN       NaN       NaN
# ...                                   ...          ...       ...       ...
# 1905  Product used for unknown indication            1  20231210  20231214
# 1906             Type 2 diabetes mellitus          NaN       NaN       NaN
# 1907  Product used for unknown indication            1  20230619  20230801
# 1908                       Weight control            1      2020      2021
# 1909                     Weight decreased            1  20210701  20210801
#
#       dur dur_cod
# 0       3     MON
# 1     NaN     NaN
# 2     NaN     NaN
# 3     NaN     NaN
# 4     NaN     NaN
# ...   ...     ...
# 1905    4     DAY
# 1906  NaN     NaN
# 1907   43     DAY
# 1908  NaN     NaN
# 1909  NaN     NaN
#
# [1910 rows x 52 columns]

# %%
##yearly data for 2022
dfs_2022 = data_extraction(2022, root_path)

##concatenate the returned dfs
data_2022 = pd.concat(dfs_2022, ignore_index = True)

##display data
data_2022
# Out:
#        primaryid    caseid caseversion i_f_code  event_dt    mfr_dt  \
# 0     1277830944  12778309          44        F       NaN  20220119
# 1      128620824  12862082           4        F  20150515  20220203
# 2     1352573514  13525735          14        F  20170417  20220103
# 3     1494356917  14943569          17        F  20160501  20220203
# 4     1522229618  15222296          18        F  20180101  20220310
# ...          ...       ...         ...      ...       ...       ...
# 1460   217920111  21792011           1        I  20221025  20221219
# 1461   217920111  21792011           1        I  20221025  20221219
# 1462   217982491  21798249           1        I       NaN  20221219
# 1463   217982491  21798249           1        I       NaN  20221219
# 1464   218008201  21800820           1        I  20221201  20221227
#
#      init_fda_dt    fda_dt rept_cod            auth_num  ... dose_unit  \
# 0       20160926  20220126      EXP                 NaN  ...       NaN
# 1       20161019  20220210      EXP                 NaN  ...        MG
# 2       20170509  20220118      EXP                 NaN  ...       NaN
# 3       20180528  20220209      EXP                 NaN  ...       NaN
# 4       20180731  20220324      EXP                 NaN  ...       NaN
# ...          ...       ...      ...                 ...  ...       ...
# 1460    20221229  20221229      EXP  SE-MPA-2022-022502  ...        MG
# 1461    20221229  20221229      EXP  SE-MPA-2022-022502  ...        MG
# 1462    20221230  20221230      EXP                 NaN  ...        MG
# 1463    20221230  20221230      EXP                 NaN  ...       NaN
# 1464    20221230  20221230      EXP                 NaN  ...       NaN
#
#                    dose_form dose_freq indi_drug_seq  \
# 0                    Capsule       NaN           122
# 1                        NaN        QD            10
# 2                        NaN       NaN            20
# 3                        NaN       NaN            49
# 4                        NaN       NaN           NaN
# ...                      ...       ...           ...
# 1460  Solution for injection        QD           NaN
# 1461  Solution for injection        QD             2
# 1462  Solution for injection        QD             3
# 1463  Solution for injection       NaN           NaN
# 1464                 Capsule        QD             1
#
#                                   indi_pt dsg_drug_seq  start_dt    end_dt  \
# 0     Product used for unknown indication          NaN       NaN       NaN
# 1                       Diabetes mellitus          NaN       NaN       NaN
# 2     Product used for unknown indication          NaN       NaN       NaN
# 3     Product used for unknown indication          NaN       NaN       NaN
# 4                                     NaN          NaN       NaN       NaN
# ...                                   ...          ...       ...       ...
# 1460                                  NaN            1       NaN  20221128
# 1461                              Obesity            2  20221014       NaN
# 1462  Product used for unknown indication          NaN       NaN       NaN
# 1463                                  NaN          NaN       NaN       NaN
# 1464  Product used for unknown indication            1  20221210  20221224
#
#       dur dur_cod
# 0     NaN     NaN
# 1     NaN     NaN
# 2     NaN     NaN
# 3     NaN     NaN
# 4     NaN     NaN
# ...   ...     ...
# 1460  NaN     NaN
# 1461  NaN     NaN
# 1462  NaN     NaN
# 1463  NaN     NaN
# 1464   14     DAY
#
# [1465 rows x 52 columns]

# %%
##yearly data for 2021
dfs_2021 = data_extraction(2021, root_path)

##concatenate the returned dfs 
data_2021 = pd.concat(dfs_2021, ignore_index = True)

##display data
data_2021
# Out:
#        primaryid    caseid caseversion i_f_code  event_dt    mfr_dt  \
# 0      136618683  13661868           3        F       NaN  20210315
# 1      137730739  13773073           9        F      2009  20210205
# 2      148792523  14879252           3        F       NaN  20210108
# 3     1522229610  15222296          10        F      2018  20201224
# 4      152836843  15283684           3        F      2018  20210317
# ...          ...       ...         ...      ...       ...       ...
# 1585   202636771  20263677           1        I       NaN  20211221
# 1586   202640121  20264012           1        I       NaN  20211219
# 1587   202647141  20264714           1        I  20211209  20211224
# 1588    74735216   7473521           6        F  20090401  20211023
# 1589    74735216   7473521           6        F  20090401  20211023
#
#      init_fda_dt    fda_dt rept_cod              auth_num  ... dose_unit  \
# 0       20170616  20210326      EXP                   NaN  ...        MG
# 1       20170720  20210216      EXP                   NaN  ...       NaN
# 2       20180511  20210115      EXP                   NaN  ...       NaN
# 3       20180731  20210102      EXP                   NaN  ...       NaN
# 4       20180816  20210324      PER                   NaN  ...        MG
# ...          ...       ...      ...                   ...  ...       ...
# 1585    20211231  20211231      EXP                   NaN  ...       NaN
# 1586    20211231  20211231      EXP  GB-MHRA-ADR 26338435  ...       NaN
# 1587    20211231  20211231      EXP                   NaN  ...        MG
# 1588    20100714  20211029      EXP  GB-MHRA-ADR 20650063  ...       NaN
# 1589    20100714  20211029      EXP  GB-MHRA-ADR 20650063  ...       NaN
#
#       dose_form dose_freq indi_drug_seq                              indi_pt  \
# 0       CAPSULE       NaN             2  Product used for unknown indication
# 1           NaN       NaN           NaN                                  NaN
# 2           NaN       NaN           NaN                                  NaN
# 3           NaN       NaN           NaN                                  NaN
# 4           NaN       NaN           NaN                                  NaN
# ...         ...       ...           ...                                  ...
# 1585        NaN       NaN           NaN                                  NaN
# 1586        NaN       NaN             1  Product used for unknown indication
# 1587  Injection        QD             2                    Diabetes mellitus
# 1588        NaN       TID             3                              Obesity
# 1589        NaN        QD           NaN                                  NaN
#
#      dsg_drug_seq  start_dt    end_dt  dur dur_cod
# 0             NaN       NaN       NaN  NaN     NaN
# 1              18      2020       NaN  NaN     NaN
# 2             NaN       NaN       NaN  NaN     NaN
# 3             NaN       NaN       NaN  NaN     NaN
# 4             NaN       NaN       NaN  NaN     NaN
# ...           ...       ...       ...  ...     ...
# 1585          NaN       NaN       NaN  NaN     NaN
# 1586          NaN       NaN       NaN  NaN     NaN
# 1587            2  20211130  20211202    3     DAY
# 1588            3    200903    200906  NaN     NaN
# 1589            4    200903    200906  NaN     NaN
#
# [1590 rows x 52 columns]

# %%
##yearly data for 2020
dfs_2020 = data_extraction(2020, root_path)

##concatenate the returned dfs
data_2020 = pd.concat(dfs_2020, ignore_index = True)

##display data
data_2020
# Out:
#        primaryid    caseid caseversion i_f_code  event_dt    mfr_dt  \
# 0      120963692  12096369           2        F      2007  20200326
# 1     1314962521  13149625          21        F      2017  20200218
# 2     1352573513  13525735          13        F  20170417  20191223
# 3      147306292  14730629           2        F  20180226  20200227
# 4      148324085  14832408           5        F  20080514  20200114
# ...          ...       ...         ...      ...       ...       ...
# 1696   186787311  18678731           1        I  20201211  20201221
# 1697   186830011  18683001           1        I       NaN  20201220
# 1698   186830111  18683011           1        I       NaN  20201221
# 1699   186896241  18689624           1        I       NaN  20201224
# 1700   186904621  18690462           1        I       NaN  20201222
#
#      init_fda_dt    fda_dt rept_cod              auth_num  ... dose_unit  \
# 0       20160220  20200331      EXP                   NaN  ...       NaN
# 1       20170125  20200302      EXP                   NaN  ...       NaN
# 2       20170509  20200106      EXP                   NaN  ...       NaN
# 3       20180406  20200309      EXP  GB-MHRA-ADR 24296496  ...       NaN
# 4       20180501  20200122      EXP                   NaN  ...       NaN
# ...          ...       ...      ...                   ...  ...       ...
# 1696    20201229  20201229      EXP                   NaN  ...       NaN
# 1697    20201230  20201230      EXP                   NaN  ...       NaN
# 1698    20201230  20201230      EXP                   NaN  ...       NaN
# 1699    20201231  20201231      EXP                   NaN  ...       NaN
# 1700    20201231  20201231      EXP                   NaN  ...       NaN
#
#                    dose_form dose_freq indi_drug_seq  \
# 0                        NaN       NaN           NaN
# 1                        NaN       NaN           NaN
# 2                        NaN       NaN            21
# 3     SOLUTION FOR INJECTION       NaN             1
# 4                        NaN       NaN            41
# ...                      ...       ...           ...
# 1696  SOLUTION FOR INJECTION       NaN             1
# 1697                 CAPSULE       NaN             1
# 1698                 CAPSULE       NaN             1
# 1699  SOLUTION FOR INJECTION       NaN             1
# 1700                 CAPSULE       NaN             1
#
#                                   indi_pt dsg_drug_seq start_dt    end_dt  \
# 0                                     NaN          NaN      NaN       NaN
# 1                                     NaN           17     2006       NaN
# 2     Product used for unknown indication          NaN      NaN       NaN
# 3                       Diabetes mellitus            1      NaN  20180226
# 4                        Weight decreased           41     2007       NaN
# ...                                   ...          ...      ...       ...
# 1696  Product used for unknown indication          NaN      NaN       NaN
# 1697  Product used for unknown indication          NaN      NaN       NaN
# 1698  Product used for unknown indication          NaN      NaN       NaN
# 1699  Product used for unknown indication            1   201906       NaN
# 1700                     Weight loss diet          NaN      NaN       NaN
#
#       dur dur_cod
# 0     NaN     NaN
# 1     NaN     NaN
# 2     NaN     NaN
# 3     NaN     NaN
# 4     NaN     NaN
# ...   ...     ...
# 1696  NaN     NaN
# 1697  NaN     NaN
# 1698  NaN     NaN
# 1699  NaN     NaN
# 1700  NaN     NaN
#
# [1701 rows x 52 columns]

# %%
##five years data (2020-2024)
dfs_1 = [data_2020, data_2021, data_2022, data_2023, data_2024]

##merge the five years data into one df
five_yrs_data = pd.concat(dfs_1, ignore_index = True)

##display data
five_yrs_data
# Out:
#        primaryid    caseid caseversion i_f_code  event_dt    mfr_dt  \
# 0      120963692  12096369           2        F      2007  20200326
# 1     1314962521  13149625          21        F      2017  20200218
# 2     1352573513  13525735          13        F  20170417  20191223
# 3      147306292  14730629           2        F  20180226  20200227
# 4      148324085  14832408           5        F  20080514  20200114
# ...          ...       ...         ...      ...       ...       ...
# 8456   247864171  24786417           1        I  20240801  20241218
# 8457   247901862  24790186           2        F       NaN  20241226
# 8458   247912301  24791230           1        I  20241214  20241219
# 8459   247913931  24791393           1        I  20220201  20241220
# 8460   247914061  24791406           1        I  20241213  20241219
#
#      init_fda_dt    fda_dt rept_cod              auth_num  ... dose_unit  \
# 0       20160220  20200331      EXP                   NaN  ...       NaN
# 1       20170125  20200302      EXP                   NaN  ...       NaN
# 2       20170509  20200106      EXP                   NaN  ...       NaN
# 3       20180406  20200309      EXP  GB-MHRA-ADR 24296496  ...       NaN
# 4       20180501  20200122      EXP                   NaN  ...       NaN
# ...          ...       ...      ...                   ...  ...       ...
# 8456    20241230  20241230      EXP                   NaN  ...       NaN
# 8457    20241230  20241231      PER                   NaN  ...       NaN
# 8458    20241230  20241230      EXP                   NaN  ...        MG
# 8459    20241231  20241231      EXP                   NaN  ...        MG
# 8460    20241231  20241231      EXP                   NaN  ...        MG
#
#                    dose_form dose_freq indi_drug_seq  \
# 0                        NaN       NaN           NaN
# 1                        NaN       NaN           NaN
# 2                        NaN       NaN            21
# 3     SOLUTION FOR INJECTION       NaN             1
# 4                        NaN       NaN            41
# ...                      ...       ...           ...
# 8456  Solution for injection       NaN             2
# 8457                 Capsule       NaN             1
# 8458  Solution for injection        QD             1
# 8459  Solution for injection        QD             1
# 8460  Solution for injection        QD             1
#
#                                   indi_pt dsg_drug_seq  start_dt    end_dt  \
# 0                                     NaN          NaN       NaN       NaN
# 1                                     NaN           17      2006       NaN
# 2     Product used for unknown indication          NaN       NaN       NaN
# 3                       Diabetes mellitus            1       NaN  20180226
# 4                        Weight decreased           41      2007       NaN
# ...                                   ...          ...       ...       ...
# 8456                       Weight control            2    202408       NaN
# 8457                     Weight decreased            1  20241224       NaN
# 8458                              Obesity          NaN       NaN       NaN
# 8459                              Obesity            1    202202    202203
# 8460  Product used for unknown indication            1  20241206  20241214
#
#       dur dur_cod
# 0     NaN     NaN
# 1     NaN     NaN
# 2     NaN     NaN
# 3     NaN     NaN
# 4     NaN     NaN
# ...   ...     ...
# 8456  NaN     NaN
# 8457  NaN     NaN
# 8458  NaN     NaN
# 8459  NaN     NaN
# 8460    8     DAY
#
# [8461 rows x 52 columns]

# %%
##yearly data for 2019
dfs_2019 = data_extraction(2019, root_path, 'latin-1')

##concatenate the returned dfs
data_2019 = pd.concat(dfs_2019, ignore_index = True)

##display data
data_2019
# Out:
#        primaryid    caseid caseversion i_f_code  event_dt    mfr_dt  \
# 0      105110067  10511006           7        F       NaN  20190111
# 1      121928105  12192810           5        F  20160212  20190107
# 2      127370444  12737044           4        F  20160902  20190213
# 3     1302531011  13025310          11        F    201602  20190312
# 4      131601416  13160141           6        F  20120220  20190304
# ...          ...       ...         ...      ...       ...       ...
# 1877   172138441  17213844           1        I       NaN  20191216
# 1878   172138441  17213844           1        I       NaN  20191216
# 1879   172138441  17213844           1        I       NaN  20191216
# 1880   172138441  17213844           1        I       NaN  20191216
# 1881   172138441  17213844           1        I       NaN  20191216
#
#      init_fda_dt    fda_dt rept_cod auth_num  ... dose_unit  dose_form  \
# 0       20141010  20190122      PER      NaN  ...       NaN        NaN
# 1       20160318  20190116      EXP      NaN  ...       NaN        NaN
# 2       20160913  20190218      EXP      NaN  ...       NaN        NaN
# 3       20161214  20190322      EXP      NaN  ...       NaN        NaN
# 4       20170127  20190307      EXP      NaN  ...       NaN        NaN
# ...          ...       ...      ...      ...  ...       ...        ...
# 1877    20191230  20191230      EXP      NaN  ...        MG  INJECTION
# 1878    20191230  20191230      EXP      NaN  ...        MG  INJECTION
# 1879    20191230  20191230      EXP      NaN  ...       NaN  INJECTION
# 1880    20191230  20191230      EXP      NaN  ...        MG  INJECTION
# 1881    20191230  20191230      EXP      NaN  ...       NaN  INJECTION
#
#      dose_freq indi_drug_seq                              indi_pt  \
# 0          NaN           NaN                                  NaN
# 1          NaN             8  Product used for unknown indication
# 2          NaN           NaN                                  NaN
# 3          NaN             4  Product used for unknown indication
# 4           QD            71                    Diabetes mellitus
# ...        ...           ...                                  ...
# 1877        QD           NaN                                  NaN
# 1878        QD           NaN                                  NaN
# 1879       NaN           NaN                                  NaN
# 1880        QD           NaN                                  NaN
# 1881       NaN           NaN                                  NaN
#
#      dsg_drug_seq start_dt    end_dt  dur dur_cod
# 0             NaN      NaN       NaN  NaN     NaN
# 1             NaN      NaN       NaN  NaN     NaN
# 2              11      NaN  20160901  NaN     NaN
# 3             NaN      NaN       NaN  NaN     NaN
# 4             NaN      NaN       NaN  NaN     NaN
# ...           ...      ...       ...  ...     ...
# 1877          NaN      NaN       NaN  NaN     NaN
# 1878          NaN      NaN       NaN  NaN     NaN
# 1879          NaN      NaN       NaN  NaN     NaN
# 1880          NaN      NaN       NaN  NaN     NaN
# 1881          NaN      NaN       NaN  NaN     NaN
#
# [1882 rows x 52 columns]

# %%
##yearly data for 2018
dfs_2018 = data_extraction(2018, root_path)

##concatenate the returned dfs
data_2018 = pd.concat(dfs_2018, ignore_index = True)

##display data
data_2018
# Out:
#        primaryid    caseid caseversion i_f_code  event_dt    mfr_dt  \
# 0      121883812  12188381           2        F  20150408  20180108
# 1      121895522  12189552           2        F       NaN  20180306
# 2     1258207112  12582071          12        F  20160629  20180314
# 3      130253109  13025310           9        F    201602  20180126
# 4      130594343  13059434           3        F       NaN  20180207
# ...          ...       ...         ...      ...       ...       ...
# 1724   157858001  15785800           1        I  20181101       NaN
# 1725   158634781  15863478           1        I  20180909       NaN
# 1726   826565868   8265658          68        F    201105  20181028
# 1727   846873712   8468737          12        F      2003  20181127
# 1728    86628824   8662882           4        F  20020424  20181016
#
#      init_fda_dt    fda_dt rept_cod auth_num  ... dose_unit dose_form  \
# 0       20160317  20180108      EXP      NaN  ...        MG       NaN
# 1       20160318  20180314      EXP      NaN  ...       NaN       NaN
# 2       20160722  20180321      EXP      NaN  ...       NaN       NaN
# 3       20161214  20180208      EXP      NaN  ...       NaN       NaN
# 4       20161223  20180215      PER      NaN  ...       NaN       NaN
# ...          ...       ...      ...      ...  ...       ...       ...
# 1724    20181212  20181212      DIR      NaN  ...       NaN       NaN
# 1725    20181228  20181228      DIR      NaN  ...        MG       NaN
# 1726    20111128  20181108      EXP      NaN  ...        MG       NaN
# 1727    20120320  20181205      EXP      NaN  ...        MG   CAPSULE
# 1728    20120712  20181027      EXP      NaN  ...        MG       NaN
#
#      dose_freq indi_drug_seq                              indi_pt  \
# 0          NaN            20             Type 2 diabetes mellitus
# 1          NaN           NaN                                  NaN
# 2          NaN             5                       Weight control
# 3          NaN            14  Product used for unknown indication
# 4          NaN             1  Product used for unknown indication
# ...        ...           ...                                  ...
# 1724       NaN             1                    Diabetes mellitus
# 1725        QD             1                    Diabetes mellitus
# 1726       NaN            54                     Weight decreased
# 1727        QD           NaN                                  NaN
# 1728       TID             8                       Weight control
#
#      dsg_drug_seq  start_dt    end_dt  dur dur_cod
# 0              20  20130724  20131107  NaN     NaN
# 1             NaN       NaN       NaN  NaN     NaN
# 2               5      2013       NaN  NaN     NaN
# 3             NaN       NaN       NaN  NaN     NaN
# 4             NaN       NaN       NaN  NaN     NaN
# ...           ...       ...       ...  ...     ...
# 1724            1  20180416  20181101  NaN     NaN
# 1725            1  20180809  20181106  NaN     NaN
# 1726           54    201708       NaN  NaN     NaN
# 1727           59  20030211       NaN  NaN     NaN
# 1728            8      2004       NaN  NaN     NaN
#
# [1729 rows x 52 columns]

# %%
##yearly data for 2017
dfs_2017 = data_extraction(2017, root_path)

##concatenate the returned dfs
data_2017 = pd.concat(dfs_2017, ignore_index = True)

##display data
data_2017
# Out:
#        primaryid    caseid caseversion i_f_code  event_dt    mfr_dt  \
# 0     1015990810  10159908          10        F    201312  20170203
# 1      104070864  10407086           4        F      2014  20170119
# 2      117918928  11791892           8        F       NaN  20170118
# 3      120839037  12083903           7        F    201602  20170221
# 4      122400272  12240027           2        F       NaN  20160504
# ...          ...       ...         ...      ...       ...       ...
# 2365   143321261  14332126           1        I       NaN  20171218
# 2366   143323591  14332359           1        I       NaN  20171223
# 2367   143375491  14337549           1        I       NaN  20171031
# 2368   143375491  14337549           1        I       NaN  20171031
# 2369   143430611  14343061           1        I  20080812       NaN
#
#      init_fda_dt    fda_dt rept_cod       auth_num  ... dose_unit  \
# 0       20140508  20170213      EXP            NaN  ...       NaN
# 1       20140825  20170123      PER            NaN  ...       NaN
# 2       20151201  20170119      PER            NaN  ...       NaN
# 3       20160217  20170307      EXP            NaN  ...       NaN
# 4       20160405  20170316      PER            NaN  ...       NaN
# ...          ...       ...      ...            ...  ...       ...
# 2365    20171228  20171228      EXP            NaN  ...       NaN
# 2366    20171228  20171228      EXP            NaN  ...       NaN
# 2367    20171229  20171229      EXP            NaN  ...        MG
# 2368    20171229  20171229      EXP            NaN  ...        MG
# 2369    20171231  20171231      DIR  US-FDA-393280  ...       NaN
#
#                    dose_form dose_freq indi_drug_seq  \
# 0                        NaN       NaN           NaN
# 1                        NaN       NaN           NaN
# 2                    CAPSULE       NaN            10
# 3                        NaN       NaN           NaN
# 4                        NaN       NaN             1
# ...                      ...       ...           ...
# 2365  SOLUTION FOR INJECTION       NaN             1
# 2366                     NaN       NaN             1
# 2367  SOLUTION FOR INJECTION       NaN             1
# 2368  SOLUTION FOR INJECTION        QD           NaN
# 2369                     NaN       NaN             1
#
#                                   indi_pt dsg_drug_seq  start_dt    end_dt  \
# 0                                     NaN            2    201402       NaN
# 1                                     NaN          NaN       NaN       NaN
# 2     Product used for unknown indication           10      2006       NaN
# 3                                     NaN          NaN       NaN       NaN
# 4     Product used for unknown indication          NaN       NaN       NaN
# ...                                   ...          ...       ...       ...
# 2365  Product used for unknown indication          NaN       NaN       NaN
# 2366  Product used for unknown indication          NaN       NaN       NaN
# 2367                     Weight decreased          NaN       NaN       NaN
# 2368                                  NaN          NaN       NaN       NaN
# 2369                      Weight abnormal            1  20080812  20100410
#
#       dur dur_cod
# 0     NaN     NaN
# 1     NaN     NaN
# 2     NaN     NaN
# 3     NaN     NaN
# 4     NaN     NaN
# ...   ...     ...
# 2365  NaN     NaN
# 2366  NaN     NaN
# 2367  NaN     NaN
# 2368  NaN     NaN
# 2369  NaN     NaN
#
# [2370 rows x 52 columns]

# %%
##yearly data for 2016
dfs_2016 = data_extraction(2016, root_path)

##concatenate the returned dfs
data_2016 = pd.concat(dfs_2016, ignore_index = True)

##display data
data_2016
# Out:
#       primaryid    caseid caseversion i_f_code  event_dt    mfr_dt  \
# 0     100189298  10018929           8        F  20121203  20160302
# 1     105123726  10512372           6        F  20140913  20160128
# 2     111576402  11157640           2        F       NaN  20160225
# 3     111697402  11169740           2        F       NaN  20160225
# 4     111736652  11173665           2        F       NaN  20160225
# ...         ...       ...         ...      ...       ...       ...
# 2483  130756601  13075660           1        I  20161201  20161202
# 2484   81695184   8169518           4        F       NaN  20160622
# 2485   81695184   8169518           4        F       NaN  20160622
# 2486   81742183   8174218           3        F      2011  20111108
# 2487   81742183   8174218           3        F      2011  20111108
#
#      init_fda_dt    fda_dt rept_cod        auth_num  ... dose_unit  dose_form  \
# 0       20140318  20160307      EXP             NaN  ...       NaN        NaN
# 1       20141010  20160209      EXP             NaN  ...       NaN        NaN
# 2       20150603  20160309      EXP             NaN  ...        DF        NaN
# 3       20150606  20160309      EXP             NaN  ...       NaN        NaN
# 4       20150609  20160309      EXP  US-FDA-7468998  ...        DF        NaN
# ...          ...       ...      ...             ...  ...       ...        ...
# 2483    20161230  20161230      PER             NaN  ...       NaN        NaN
# 2484    20111005  20161104      PER             NaN  ...       NaN    CAPSULE
# 2485    20111005  20161104      PER             NaN  ...       NaN    CAPSULE
# 2486    20111010  20161026      EXP             NaN  ...        MG  INJECTION
# 2487    20111010  20161026      EXP             NaN  ...        MG  INJECTION
#
#      dose_freq indi_drug_seq                              indi_pt  \
# 0          NaN           NaN                                  NaN
# 1          NaN            13  Product used for unknown indication
# 2          TID             2  Product used for unknown indication
# 3          NaN             2  Product used for unknown indication
# 4          TID             2  Product used for unknown indication
# ...        ...           ...                                  ...
# 2483       NaN             3                     Weight decreased
# 2484       NaN             1                     Weight loss diet
# 2485       NaN           NaN                                  NaN
# 2486        QD             8                    Diabetes mellitus
# 2487        QD           NaN                                  NaN
#
#      dsg_drug_seq start_dt    end_dt  dur dur_cod
# 0             NaN      NaN       NaN  NaN     NaN
# 1              13     2012       NaN  NaN     NaN
# 2             NaN      NaN       NaN  NaN     NaN
# 3             NaN      NaN       NaN  NaN     NaN
# 4             NaN      NaN       NaN  NaN     NaN
# ...           ...      ...       ...  ...     ...
# 2483          NaN      NaN       NaN  NaN     NaN
# 2484            1      NaN  20110921  NaN     NaN
# 2485            2     2015      2015  NaN     NaN
# 2486          NaN      NaN       NaN  NaN     NaN
# 2487          NaN      NaN       NaN  NaN     NaN
#
# [2488 rows x 52 columns]

# %%
##yearly data for 2015
dfs_2015 = data_extraction(2015, root_path)

##concatenate the returned dfs
data_2015 = pd.concat(dfs_2015, ignore_index = True)

##display data
data_2015
# Out:
#       primaryid    caseid caseversion i_f_code  event_dt    mfr_dt  \
# 0     100593752  10059375           2        F  20130509  20140407
# 1     100600032  10060003           2        F       NaN  20131121
# 2     100601192  10060119           2        F       NaN  20141218
# 3     102706412  10270641           2        F  20140414  20140617
# 4     103611546  10361154           6        F  20140724  20150304
# ...         ...       ...         ...      ...       ...       ...
# 2389  118830901  11883090           1        I       NaN  20151229
# 2390  118849651  11884965           1        I  20150922       NaN
# 2391   91003424   9100342           4        F  20130125  20151204
# 2392   99153282   9915328           2        F  20110617  20110607
# 2393   99274482   9927448           2        F       NaN  20140221
#
#      init_fda_dt    fda_dt rept_cod              auth_num  ... dose_unit  \
# 0       20140404  20150210      EXP                   NaN  ...       NaN
# 1       20140404  20150210      EXP                   NaN  ...       NaN
# 2       20140404  20150107      EXP                   NaN  ...       NaN
# 3       20140701  20140701      EXP  GB-MHRA-ADR 22571245  ...        MG
# 4       20140804  20150312      EXP                   NaN  ...       NaN
# ...          ...       ...      ...                   ...  ...       ...
# 2389    20151231  20151231      EXP                   NaN  ...       NaN
# 2390    20151231  20151231      DIR                   NaN  ...        MG
# 2391    20130215  20151211      EXP                   NaN  ...       NaN
# 2392    20140221  20151118      EXP                   NaN  ...       NaN
# 2393    20140227  20151216      EXP                   NaN  ...       NaN
#
#      dose_form dose_freq indi_drug_seq                              indi_pt  \
# 0      CAPSULE       BID             1  Product used for unknown indication
# 1      CAPSULE       NaN             1                     Weight decreased
# 2      CAPSULE       NaN             1  Product used for unknown indication
# 3          NaN       TID             5  Product used for unknown indication
# 4          NaN       NaN             8             Type 2 diabetes mellitus
# ...        ...       ...           ...                                  ...
# 2389       NaN       NaN             1                     Weight loss diet
# 2390       NaN        QD           NaN                                  NaN
# 2391       NaN       NaN             2                    Diabetes mellitus
# 2392       NaN       NaN           NaN                                  NaN
# 2393       NaN       NaN             1  Product used for unknown indication
#
#      dsg_drug_seq  start_dt    end_dt  dur dur_cod
# 0               1  20130510  20130530  NaN     NaN
# 1             NaN       NaN       NaN  NaN     NaN
# 2             NaN       NaN       NaN  NaN     NaN
# 3             NaN       NaN       NaN  NaN     NaN
# 4               8  20140109       NaN  NaN     NaN
# ...           ...       ...       ...  ...     ...
# 2389          NaN       NaN       NaN  NaN     NaN
# 2390            1  20150901  20150925  NaN     NaN
# 2391            2    201012       NaN  NaN     NaN
# 2392          NaN       NaN       NaN  NaN     NaN
# 2393          NaN       NaN       NaN  NaN     NaN
#
# [2394 rows x 52 columns]

# %%
##five years data (2015-2019)
dfs_2 = [data_2015, data_2016, data_2017, data_2018, data_2019]

##merge the dfs
five_yrs_data_2 = pd.concat(dfs_2, ignore_index = True)

##dispaly data
five_yrs_data_2
# Out:
#        primaryid    caseid caseversion i_f_code  event_dt    mfr_dt  \
# 0      100593752  10059375           2        F  20130509  20140407
# 1      100600032  10060003           2        F       NaN  20131121
# 2      100601192  10060119           2        F       NaN  20141218
# 3      102706412  10270641           2        F  20140414  20140617
# 4      103611546  10361154           6        F  20140724  20150304
# ...          ...       ...         ...      ...       ...       ...
# 10858  172138441  17213844           1        I       NaN  20191216
# 10859  172138441  17213844           1        I       NaN  20191216
# 10860  172138441  17213844           1        I       NaN  20191216
# 10861  172138441  17213844           1        I       NaN  20191216
# 10862  172138441  17213844           1        I       NaN  20191216
#
#       init_fda_dt    fda_dt rept_cod              auth_num  ... dose_unit  \
# 0        20140404  20150210      EXP                   NaN  ...       NaN
# 1        20140404  20150210      EXP                   NaN  ...       NaN
# 2        20140404  20150107      EXP                   NaN  ...       NaN
# 3        20140701  20140701      EXP  GB-MHRA-ADR 22571245  ...        MG
# 4        20140804  20150312      EXP                   NaN  ...       NaN
# ...           ...       ...      ...                   ...  ...       ...
# 10858    20191230  20191230      EXP                   NaN  ...        MG
# 10859    20191230  20191230      EXP                   NaN  ...        MG
# 10860    20191230  20191230      EXP                   NaN  ...       NaN
# 10861    20191230  20191230      EXP                   NaN  ...        MG
# 10862    20191230  20191230      EXP                   NaN  ...       NaN
#
#        dose_form dose_freq indi_drug_seq                              indi_pt  \
# 0        CAPSULE       BID             1  Product used for unknown indication
# 1        CAPSULE       NaN             1                     Weight decreased
# 2        CAPSULE       NaN             1  Product used for unknown indication
# 3            NaN       TID             5  Product used for unknown indication
# 4            NaN       NaN             8             Type 2 diabetes mellitus
# ...          ...       ...           ...                                  ...
# 10858  INJECTION        QD           NaN                                  NaN
# 10859  INJECTION        QD           NaN                                  NaN
# 10860  INJECTION       NaN           NaN                                  NaN
# 10861  INJECTION        QD           NaN                                  NaN
# 10862  INJECTION       NaN           NaN                                  NaN
#
#       dsg_drug_seq  start_dt    end_dt  dur dur_cod
# 0                1  20130510  20130530  NaN     NaN
# 1              NaN       NaN       NaN  NaN     NaN
# 2              NaN       NaN       NaN  NaN     NaN
# 3              NaN       NaN       NaN  NaN     NaN
# 4                8  20140109       NaN  NaN     NaN
# ...            ...       ...       ...  ...     ...
# 10858          NaN       NaN       NaN  NaN     NaN
# 10859          NaN       NaN       NaN  NaN     NaN
# 10860          NaN       NaN       NaN  NaN     NaN
# 10861          NaN       NaN       NaN  NaN     NaN
# 10862          NaN       NaN       NaN  NaN     NaN
#
# [10863 rows x 52 columns]

# %%
##merge the ten years data
ten_yrs_data = pd.concat([five_yrs_data, five_yrs_data_2], ignore_index = True)

##display data
ten_yrs_data
# Out:
#         primaryid    caseid caseversion i_f_code  event_dt    mfr_dt  \
# 0       120963692  12096369           2        F      2007  20200326
# 1      1314962521  13149625          21        F      2017  20200218
# 2      1352573513  13525735          13        F  20170417  20191223
# 3       147306292  14730629           2        F  20180226  20200227
# 4       148324085  14832408           5        F  20080514  20200114
# ...           ...       ...         ...      ...       ...       ...
# 19319   172138441  17213844           1        I       NaN  20191216
# 19320   172138441  17213844           1        I       NaN  20191216
# 19321   172138441  17213844           1        I       NaN  20191216
# 19322   172138441  17213844           1        I       NaN  20191216
# 19323   172138441  17213844           1        I       NaN  20191216
#
#       init_fda_dt    fda_dt rept_cod              auth_num  ... dose_unit  \
# 0        20160220  20200331      EXP                   NaN  ...       NaN
# 1        20170125  20200302      EXP                   NaN  ...       NaN
# 2        20170509  20200106      EXP                   NaN  ...       NaN
# 3        20180406  20200309      EXP  GB-MHRA-ADR 24296496  ...       NaN
# 4        20180501  20200122      EXP                   NaN  ...       NaN
# ...           ...       ...      ...                   ...  ...       ...
# 19319    20191230  20191230      EXP                   NaN  ...        MG
# 19320    20191230  20191230      EXP                   NaN  ...        MG
# 19321    20191230  20191230      EXP                   NaN  ...       NaN
# 19322    20191230  20191230      EXP                   NaN  ...        MG
# 19323    20191230  20191230      EXP                   NaN  ...       NaN
#
#                     dose_form dose_freq indi_drug_seq  \
# 0                         NaN       NaN           NaN
# 1                         NaN       NaN           NaN
# 2                         NaN       NaN            21
# 3      SOLUTION FOR INJECTION       NaN             1
# 4                         NaN       NaN            41
# ...                       ...       ...           ...
# 19319               INJECTION        QD           NaN
# 19320               INJECTION        QD           NaN
# 19321               INJECTION       NaN           NaN
# 19322               INJECTION        QD           NaN
# 19323               INJECTION       NaN           NaN
#
#                                    indi_pt dsg_drug_seq start_dt    end_dt  \
# 0                                      NaN          NaN      NaN       NaN
# 1                                      NaN           17     2006       NaN
# 2      Product used for unknown indication          NaN      NaN       NaN
# 3                        Diabetes mellitus            1      NaN  20180226
# 4                         Weight decreased           41     2007       NaN
# ...                                    ...          ...      ...       ...
# 19319                                  NaN          NaN      NaN       NaN
# 19320                                  NaN          NaN      NaN       NaN
# 19321                                  NaN          NaN      NaN       NaN
# 19322                                  NaN          NaN      NaN       NaN
# 19323                                  NaN          NaN      NaN       NaN
#
#        dur dur_cod
# 0      NaN     NaN
# 1      NaN     NaN
# 2      NaN     NaN
# 3      NaN     NaN
# 4      NaN     NaN
# ...    ...     ...
# 19319  NaN     NaN
# 19320  NaN     NaN
# 19321  NaN     NaN
# 19322  NaN     NaN
# 19323  NaN     NaN
#
# [19324 rows x 52 columns]

# %%
##save to csv file

##file path
csv_file = root_path+'Ten_years_data.csv'

##save the file
ten_yrs_data.to_csv(csv_file, index = False)
